# %%
import urllib 
import lxml.html
from bs4 import BeautifulSoup 
import time
import os
import constants
import pandas as pd
import psycopg2
import re

# %%
def product_info(product_list):
    """
    This function scrapes the Pet Smart website to isolate information
    into separate variables from the url passed to it and exports the 
    information to a pickle file. The pickle file can be imported as a 
    dataframe, cleaned up, then stored into a database.

    Input:
    A list of urls of pet food product pages generated from crawler.py

    Output:

    nutrition_df.pkl
    name(str), productID(int), price(str), food_type(str), life_stage(str), 
    health_consideration(str), flavor(str),primary_ingredient(str), url(str)
    package_weight(str), , ingredient_list(str) and a set of columns iterated from the 
    "Guaranteed Analysis" portion of the product page, which lists things like 
    # %protein and % moisture."""

    nutrition_dict_list = []
    def nutrition_regex(tag_list, nutrition_dict):

        """This function goes to the Guaranteed Analysis portion of the page
           and isolates the percentage of each nutritional component listed
           into it's appropriate key.
           
           Input: a list of sections of the webpage to search and the 
           dictionary to store the information in that is defined below.
           
           Output: Key: Value pairs listing the percentage of each 
           nutritional component. Values are percentages. These get added
           to the dictionary of product information defined in the overall
           function."""

        for tag in tag_list:
            if "Guaranteed Analysis" in tag:
                new = tag.split("<br/>")  
                for i, line in enumerate(new):
                    if "Crude Protein (min" in line:
                        nutrition_dict['crude_protein_min']= \
                        re.findall("\)\s*(.*?)\s*%", line) 
                    elif "Crude Protein (max" in line:
                        nutrition_dict['crude_protein_max']= \
                        re.findall("\)\s*(.*?)\s*%", line)
                    elif "Crude Fat (min" in line:
                        nutrition_dict['crude_fat_min']= \
                        re.findall("\)\s*(.*?)\s*%", line) 
                    elif "Crude Fat (max" in line:
                        nutrition_dict['crude_fat_max']= \
                        re.findall("\)\s*(.*?)\s*%", line) 
                    elif "Crude Fiber (min" in line:
                        nutrition_dict['crude_fiber_min']= \
                        re.findall("\)\s*(.*?)\s*%", line) 
                    elif "Crude Fiber (max" in line:
                        nutrition_dict['crude_fiber_max']= \
                        re.findall("\)\s*(.*?)\s*%", line) 
                    elif "Moisture (min" in line:
                        nutrition_dict['moisture_min']= \
                        re.findall("\)\s*(.*?)\s*%", line) 
                    elif "Moisture (max" in line:
                        nutrition_dict['moisture_max']= \
                        re.findall("\)\s*(.*?)\s*%", line) 
                    elif "Ash (min" in line:
                        nutrition_dict['ash_min']= \
                        re.findall("\)\s*(.*?)\s*%", line) 
                    elif "Ash (max" in line:
                        nutrition_dict['ash_max']= \
                        re.findall("\)\s*(.*?)\s*%", line) 
                    elif "Taurine (min" in line:
                        nutrition_dict['taurine_min']= \
                        re.findall("\)\s*(.*?)\s*%", line) 
                    elif "Taurine (max" in line:
                        nutrition_dict['taurine_max']= \
                        re.findall("\)\s*(.*?)\s*%", line) 
                    else:                        
                        nutrition_dict['tag'] = None
            else:
                None
        return nutrition_dict

    #Open product pages from the product url list created from the crawler function      
    for url in product_list: 

        nutrition_dict = {}        
        try:
        # Open each url, turn each page into a Beautiful Soup object
            r = urllib.urlopen(url)
            soup_page = BeautifulSoup(r, 'lxml') #'html.parser'
        except:
            print "Error getting page" 

        #check HTTP status codes while running (200 is good)
        print urllib.urlopen(url).getcode()

        try:        
            name_box = soup_page.find('div', attrs={'class': 'product-name'})
            prodID_box = soup_page.find('span', attrs={'class': 'productID'})        
            nutrition_dict['name'] = name_box.get_text().strip()  
            nutrition_dict['product_id'] = prodID_box.get_text()
        except:
            pass   

        try:
            price_box = soup_page.find('span', attrs={'class': 'price-regular'})
            nutrition_dict['price'] = price_box.get_text()
        except:
            nutrition_dict['price']=''
        try:
            nutrition_dict['url']=url
        except:
            nutrition_dict['url']=''            

        #This section defines the places interesting variables could be.
        #The html is messy, so I will define all the "b" tags and 
        #iterate through them below.   

        type_box = soup_page.find('div', attrs={'class': 'tab-content'})

        try:
            zero = type_box.find_all('b')[0]
        except:
            zero =  ''             
        try:
            one = type_box.find_all('b')[1]
        except:
            one = ''
        try:
            two = type_box.find_all('b')[2]
        except:
            two = ''
        try:
            three = type_box.find_all('b')[3]
        except:
            three = ''
        try:
            four = type_box.find_all('b')[4]
        except:
            four = ''
        try:
            five = type_box.find_all('b')[5]
        except:
            five = ''                      
        try:
            six = type_box.find_all('b')[6]
        except:
            six = ''
        try:
            seven = type_box.find_all('b')[7]
        except:
            seven = ''
        try:
            eight = type_box.find_all('b')[8]
        except:
            eight = ''
        try:
            nine = type_box.find_all('b')[9]
        except:
            nine = ''

        #Make a list of the variables
        info_list = [zero, one, two, three, four, five, six, 
                     seven, eight, nine] 

        #Iterate through the list to find where the information is
        #and put it into its appropriate key.
        for info in info_list:           
            if "Ingredients:" in info:  
                nutrition_dict['ingredients'] = info.next_sibling
            elif 'Food Type:' in info:
                nutrition_dict['food_type'] = info.next_sibling.strip()  
            elif 'Life Stage:' in info:
                nutrition_dict['life_stage'] = info.next_sibling.strip() 
            elif 'Health Consideration:' in info:
                nutrition_dict['health_consideration'] = \
                info.next_sibling.strip() 
            elif 'Flavor:' in info:
                nutrition_dict['flavor'] = info.next_sibling.strip() 
            elif 'Primary Ingredient:' in info:
                nutrition_dict['primary_ingredient'] = info.next_sibling
            elif 'Package Weight:' in info:
                nutrition_dict['package_weight'] = info.next_sibling.strip()
            else:
                None

        #This section defines the places "Guaranteed Analysis" could be.
        #The html is messy, so I will look in several places, and parse
        #through it using the nutrition_regex function above (called below).                    
        try:
            tag0 = str(type_box.findAll('p')[0].next_sibling).strip()
        except:
            tag0 = '' 
        try:
            tag1 = str(type_box.findAll('p')[1].next_sibling).strip()
        except:
            tag1 = ''       
        try:
            tag2 = str(type_box.findAll('p')[2].next_sibling).strip()
        except:
            tag2 = ''     
        try:
            tag3 = str(type_box.findAll('p')[3].next_sibling).strip()
        except:
            tag3 = ''
        try:
            tag4 = str(type_box.findAll('p')[4].next_sibling).strip()
        except:
            tag4 = ''

        #Make a list of the variables
        tag_list = [tag0, tag1, tag2, tag3, tag4]               

        #This calls the nutritional information parser from above,
        #feeding in the list of places to look on the page (tags)
        #for the nutritional information
        nutrition_dict = nutrition_regex(tag_list, nutrition_dict)   

        #append all keys:values to nutrition dictionary list
        nutrition_dict_list.append(nutrition_dict)    

    #turn dictionary list into a dataframes    
    nutrition_df = pd.DataFrame(nutrition_dict_list) 

    #export the dataframe from the function as a pickle file to access later
    nutrition_df.to_pickle('product_info_df.pkl')

    return nutrition_dict_list

product_info(constants.product_urls)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# [{'ash_max': ['3.5'],
#   'crude_fat_min': ['2'],
#   'crude_fiber_max': ['1.5'],
#   'crude_protein_min': ['13'],
#   'flavor': u'COD, Sole & Shrimp',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'ingredients': u' Cod, Liver, Meat by-Products, Fish, Fish Broth, Sole, Shrimp, \r\nArtificial and Natural Flavors, Guar Gum, Added Color (Red 3 and Other Color), Calcium \r\nPhosphate, Potassium Chloride, Salt, Zinc Sulfate, Thiamine Mononitrate, Vitamin E \r\nSupplement, Ferrous Sulfate, Niacin, Manganese Sulfate, Calcium Pantothenate, Vitamin A \r\nSupplement, Copper Sulfate, Menadione Sodium Bisulfite Complex (Source of Vitamin K \r\nActivity), Pyridoxine Hydrochloride, Riboflavin Supplement, Vitamin B-12 Supplement, \r\nBiotin, Folic Acid, Vitamin D-3 Supplement, Potassium Iodide. \r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['78'],
#   'name': u'Fancy Feast\xae Classic Adult Cat Food',
#   'package_weight': u'3oz',
#   'price': u'$0.59',
#   'primary_ingredient': u' COD\xa0\r\n',
#   'product_id': u'1221059',
#   'tag': None,
#   'taurine_min': ['0.05'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/fancy-feast-classic-adult-cat-food-12865.html?cgid=200004'},
#  {'ash_max': ['3.5'],
#   'crude_fat_min': ['5'],
#   'crude_fiber_max': ['1'],
#   'crude_protein_min': ['10'],
#   'flavor': u'Mixed Grill',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'ingredients': u' Meat by-Products, Water Sufficient for Processing, Poultry by-Products, \r\nLiver, Chicken, Rice, Artificial and Natural Flavors, Salt, Guar Gum, Calcium Phosphate, \r\nAdded Color, Potassium Chloride, Carrageenan, Taurine, Zinc Sulfate, Thiamine Mononitrate, Vitamin E \r\nSupplement, Ferrous Sulfate, Niacin, Manganese Sulfate, Calcium Pantothenate, Vitamin A \r\nSupplement, Copper Sulfate, Menadione Sodium Bisulfite Complex (Source of Vitamin K \r\nActivity), Pyridoxine Hydrochloride, Riboflavin Supplement, Vitamin B-12 Supplement, \r\nBiotin, Folic Acid, Vitamin D-3 Supplement, Potassium Iodide. \r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['78'],
#   'name': u'Purina\xae Friskies\xae Classic Pat\xe9 Cat Food',
#   'package_weight': u'5.5oz',
#   'price': u'$0.48',
#   'primary_ingredient': u' Liver\xa0\r\n',
#   'product_id': u'1221026',
#   'tag': None,
#   'taurine_min': ['0.05'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/purina-friskies-classic-pate-cat-food-1610.html?cgid=200004'},
#  {'ash_max': ['2.5'],
#   'crude_fat_min': ['2.5'],
#   'crude_fiber_max': ['1.0'],
#   'crude_protein_min': ['9.0'],
#   'moisture_max': ['82.0'],
#   'name': u'Purina\xae Friskies\xae Savory Shreds Cat Food',
#   'price': u'$0.48',
#   'product_id': u'5121705',
#   'tag': None,
#   'taurine_min': ['0.05'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/purina-friskies-savory-shreds-cat-food-1547.html?cgid=200004'},
#  {'ash_max': ['2.7'],
#   'crude_fat_min': ['2'],
#   'crude_fiber_max': ['1.5'],
#   'crude_protein_min': ['12'],
#   'flavor': u'Seafood Feast',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'ingredients': u' Fish Broth, Ocean Fish, Liver, Wheat Gluten, Meat by-Products, \r\nChicken \r\nCorn Starch-Modified, Natural and Artificial Flavors, Shrimp, Corn Oil, Tricalcium Phosphate, Salt, \r\nSoy Protein Concentrate, Added Color (Red 3 and Other Color), Titanium Dioxide, Potassium Chloride, Taurine, Choline \r\nChloride, Vitamin Supplements (E, A, D3, B12), Thiamine Mononitrate (Vitamin B1), \r\nFerrous Sulfate, Zinc Sulfate, Manganese Sulfate, Pyridoxine Hydrochloride (Vitamin B6), \r\nNiacin, Calcium Pantothenate, Riboflavin Supplement (Vitamin B2), Copper Sulfate, \r\nDicalcium Phosphate, Vitamin K, Folic Acid, Cobalt Carbonate, Potassium Iodide, \r\nBiotin. \r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['78'],
#   'name': u'Fancy Feast\xae Grilled Adult Cat Food',
#   'package_weight': u'3oz',
#   'price': u'$0.59',
#   'primary_ingredient': u' Chicken Broth\r\n',
#   'product_id': u'5121709',
#   'tag': None,
#   'taurine_min': ['0.05'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/fancy-feast-grilled-adult-cat-food-12855.html?cgid=200004'},
#  {'ash_max': ['2.2'],
#   'crude_fat_min': ['6.5'],
#   'crude_fiber_max': ['0.8'],
#   'crude_protein_min': ['10.0'],
#   'flavor': u'Chicken',
#   'food_type': u'Wet Food',
#   'ingredients': <br/>,
#   'life_stage': u'Adult',
#   'moisture_max': ['78.0'],
#   'name': u'Authority\xae Pate Adult Cat Food',
#   'package_weight': u'6 oz.',
#   'price': u'$0.89',
#   'primary_ingredient': u' Chicken',
#   'product_id': u'5219423',
#   'tag': None,
#   'taurine_min': ['0.07'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/authority-pate-adult-cat-food-23731.html?cgid=200004'},
#  {'flavor': u'Turkey',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'ingredients': u' Poultry Broth, Turkey, Wheat Gluten, Liver, Meat by-Products, Corn Starch-Modified, Artificial and Natural Flavors, \r\nCalcium Phosphate, Salt, Added Color, Soy Flour, Natural Roasted Turkey Flavor, Potassium Chloride, Taurine, Choline Chloride, Thiamine Mononitrate, Vitamin E Supplement, Zinc Sulfate, \r\nNiacin, Ferrous Sulfate, CalciumPantothenate, Vitamin A Supplement, Menadione Sodium \r\nBisulfite Complex (Source of Vitamin K Activity), Pyridoxine Hydrochloride, Manganese \r\nSulfate, Riboflavin Supplement, Vitamin B-12 Supplement, Copper Sulfate, Biotin, \r\nFolic Acid, Vitamin D-3 Supplement, Potassium Iodide.\r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'name': u'Fancy Feast\xae Gravy Lovers Adult Cat Food',
#   'package_weight': u'3oz',
#   'price': u'$0.59',
#   'primary_ingredient': u' Poultry Broth\r\n',
#   'product_id': u'5164703',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/fancy-feast-gravy-lovers-adult-cat-food-12853.html?cgid=200004'},
#  {'ash_max': ['2.8'],
#   'crude_fat_min': ['2.0'],
#   'crude_fiber_max': ['1.5'],
#   'crude_protein_min': ['10.0'],
#   'flavor': u'Chicken & Cheese',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'ingredients': u' Water Sufficient For Processing, Chicken, Liver, Wheat Gluten, Meat By-products, Corn Starch-modified, Cheese, Artificial And Natural Flavors, Salt, Calcium Phosphate, Sodium Caseinate, Soy Protein Concentrate, Soybean Oil, Potassium Chloride, Spice And Coloring, Dried Whey, Taurine, Choline Chloride, Sodium Tripolyphosphate, Vitamin E Supplement, Thiamine Mononitrate, Zinc Sulfate, Ferrous Sulfate, Niacin, Sorbic Acid (a Preservative), Calcium Pantothenate, Vitamin A Supplement, Menadione Sodium Bisulfite Complex (source Of Vitamin K Activity), Copper Sulfate, Manganese Sulfate, Pyridoxine Hydrochloride, Riboflavin Supplement, Vitamin B12 Supplement, Biotin, Folic Acid, Vitamin D3 Supplement And Potassium Iodide\r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['80.0'],
#   'name': u'Purina\xae Pro Plan\xae Adult Cat Food',
#   'package_weight': u'3oz',
#   'price': '',
#   'primary_ingredient': u' Water\r\n',
#   'product_id': u'5178589',
#   'tag': None,
#   'taurine_min': ['0.05'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/purina-pro-plan-adult-cat-food-12804.html?cgid=200004'},
#  {'ash_max': ['2.7'],
#   'crude_fat_min': ['2.0'],
#   'crude_fiber_max': ['1.0'],
#   'crude_protein_min': ['11.0'],
#   'moisture_max': ['80.0'],
#   'name': u'Purina\xae Friskies\xae Prime Filets Cat Food',
#   'price': u'$0.48',
#   'product_id': u'5092179',
#   'tag': None,
#   'taurine_min': ['0.05'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/purina-friskies-prime-filets-cat-food-1510.html?cgid=200004'},
#  {'ash_max': ['2.3'],
#   'crude_fat_min': ['5.0'],
#   'crude_fiber_max': ['1.0'],
#   'crude_protein_min': ['10.0'],
#   'flavor': u'Chicken & Herring',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'ingredients': u' Chicken, Chicken Liver, Whitefish, Chicken Broth, Herring, Carrots, Natural Chicken Flavor, Sweet Potatoes, Squash, Zucchini, Dicalcium Phosphate, Guar Gum, Cranberries, Blueberries, Carrageenan, Ground Flaxseed, Potassium Chloride, Taurine, Calcium Carbonate, Iron Proteinate (a Source Of Chelated Iron), Beta-carotene, Zinc Proteinate (a Source Of Chelated Zinc), Vitamin E Supplement, Choline Chloride, Cobalt Proteinate (a Source Of Chelated Cobalt), Thiamine Mononitrate, Copper Proteinate (a Source Of Chelated Copper), Folic Acid, Manganese Proteinate (a Source Of Chelated Manganese), Niacin, D-calcium Pantothenate, Sodium Selenite, Vitamin D3 Supplement, Pyridoxine Hydrochloride, Riboflavin Supplement, Vitamin A Supplement, Vitamin B12 Supplement, Potassium Iodide And Biotin\r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['78.0'],
#   'name': u'Wellness\xae Complete Health Cat Food - Natural, Grain Free',
#   'package_weight': u'3oz',
#   'price': u'$1.49',
#   'primary_ingredient': u' Chicken\r\n',
#   'product_id': u'5153734',
#   'tag': None,
#   'taurine_min': ['0.1'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/wellness-complete-health-cat-food---natural-grain-free-12917.html?cgid=200004'},
#  {'ash_max': ['6.5'],
#   'crude_fat_max': ['15.0'],
#   'crude_fat_min': ['12.0'],
#   'crude_fiber_max': ['5.0'],
#   'crude_protein_min': ['33.0'],
#   'moisture_max': ['10.0'],
#   'name': u'Authority\xae Indoor Adult Cat Food - Chicken & Rice',
#   'price': u'$9.99',
#   'product_id': u'5220331',
#   'tag': None,
#   'taurine_min': ['0.15'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/authority-indoor-adult-cat-food---chicken-and-rice-26335.html?cgid=200004'},
#  {'ash_max': ['3'],
#   'crude_fat_min': ['2'],
#   'crude_fiber_max': ['1.5'],
#   'crude_protein_min': ['17.5'],
#   'flavor': u'Flaked Fish & Shrimp',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'ingredients': u' Ocean Fish, Fish Broth, Shrimp, Tricalcium Phosphate, Vegetable \r\nOil, Guar Gum, Vitamin E Supplement, Vitamin A Acetate, Sodium Nitrite (to Promote \r\nColor Retention), Zinc Sulfate.\r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['78'],
#   'name': u'Fancy Feast\xae Flaked Adult Cat Food',
#   'package_weight': u'3 oz',
#   'price': u'$0.59',
#   'primary_ingredient': u' Ocean Fish\r\n',
#   'product_id': u'1221553',
#   'tag': None,
#   'taurine_min': ['0.05'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/fancy-feast-flaked-adult-cat-food-12861.html?cgid=200004'},
#  {'ash_max': ['2.7'],
#   'crude_fat_min': ['4.0'],
#   'crude_fiber_max': ['1.5'],
#   'crude_protein_min': ['10.0'],
#   'flavor': u'Chicken',
#   'food_type': u'Wet Food',
#   'ingredients': <br/>,
#   'life_stage': u'Adult',
#   'moisture_max': ['80.0'],
#   'name': u'Authority\xae Adult Cat Food - Flaked',
#   'package_weight': u'6 oz.',
#   'price': u'$0.89',
#   'primary_ingredient': u' Chicken Broth',
#   'product_id': u'5219391',
#   'tag': None,
#   'taurine_min': ['0.05'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/authority-adult-cat-food---flaked-23729.html?cgid=200004'},
#  {'name': u'Purely Fancy Feast\xae Adult Cat Food',
#   'price': '',
#   'product_id': u'5141590',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/purely-fancy-feast-adult-cat-food-3111.html?cgid=200004'},
#  {'crude_fat_min': ['... 16.0'],
#   'crude_fiber_max': ['... 6.0'],
#   'crude_protein_min': ['... 38.0'],
#   'flavor': u'Other',
#   'food_type': u'Dry Food',
#   'health_consideration': u'General Health',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': 
\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'name': u'Fancy Feast\xae Grilled Delights Cat Food',
#   'package_weight': u'3oz',
#   'price': u'$0.59',
#   'primary_ingredient': u' Fish Broth\r\n',
#   'product_id': u'5159870',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/fancy-feast-grilled-delights-cat-food-12859.html?cgid=200004'},
#  {'ash_max': ['3.0'],
#   'crude_fat_min': ['0.05'],
#   'crude_fiber_max': ['1.0'],
#   'crude_protein_min': ['7.0'],
#   'flavor': u'Tuna, Shrimp & Whitefish',
#   'food_type': u'Cat Food',
#   'ingredients': <br/>,
#   'life_stage': u'Adult',
#   'moisture_max': ['92.0'],
#   'name': u'Fancy Feast\xae Classic Broths Cat Food',
#   'package_weight': u'1.4 oz.',
#   'price': '',
#   'primary_ingredient': u' Fish Broth',
#   'product_id': u'5221047',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/fancy-feast-classic-broths-cat-food-26823.html?cgid=200004'},
#  {'ash_max': ['2.7'],
#   'crude_fat_min': ['5.0'],
#   'crude_fiber_max': ['1.5'],
#   'crude_protein_min': ['10.0'],
#   'flavor': u'Turkey & Giblet',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'ingredients': u' Meat By-products, Poultry By-products, Sufficient Water For Processing, Turkey, Poultry Giblets, Fish, Guar Gum, Salt, Added Color, Potassium Chloride, Carrageenan, Sodium Tripolyphosphate, Vitamin E Supplement, Vitamin A Supplement, Vitamin D3 Supplement, Vitamin B12 Supplement, Thiamine Mononitrate, Niacin, D-calcium Pantothenate, Pyridoxine Hydrochloride, Riboflavin Supplement, Folic Acid, Biotin, Ferrous Sulfate, Zinc Oxide, Copper Proteinate, Manganous Sulfate, Potassium Iodide, Sodium Selenite, Choline Chloride And Taurine\r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['78.0'],
#   'name': u'Grreat Choice\xae Pate Adult Cat Food',
#   'package_weight': u'5.5oz',
#   'price': u'$0.43',
#   'primary_ingredient': u' Turkey\r\n',
#   'product_id': u'5171300',
#   'tag': None,
#   'taurine_min': ['0.05'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/grreat-choice-pate-adult-cat-food-12869.html?cgid=200004'},
#  {'flavor': u'Tuna Florentine',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'ingredients': u' Fish broth, Tuna, Wheat Gluten, Liver, Chicken, Meat by-Products, \r\nSpinach, Corn Starch-Modified, Artificial and Natural Flavors, Added Color (Red 3 and \r\nOther Color), Calcium Phosphate, Salt, Soy Protein Concentrate, Potassium Chloride, \r\nTaurine, Choline Chloride, Thiamine Mononitrate, Vitamin E Supplement, Zinc Sulfate, \r\nFerrous Sulfate, Niacin, Calcium Pantothenate, Vitamin A Supplement, Copper Sulfate, \r\nManganese Sulfate, Menadione Sodium Bisulfite Complex (Source of Vitamin K Activity), \r\nPyridoxine Hydrochloride, Riboflavin Supplement, Vitamin B-12 Supplement, Biotin, \r\nFolic Acid, Vitamin D-3 Supplement, Potassium Iodide\r\n\r\n\t\t\t\t\t',
#   'life_stage': u'Adult 1-10 yrs',
#   'name': u'Fancy Feast\xae Medleys Florentine Adult Cat Food',
#   'package_weight': u'3oz',
#   'price': '',
#   'primary_ingredient': u' Fish Broth\r\n',
#   'product_id': u'5113393',
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/fancy-feast-medleys-florentine-adult-cat-food-12849.html?cgid=200004'},
#  {'flavor': u'Chicken Primavera',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'ingredients': u'

#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'ingredients': u' Water Sufficient for Processing, Chicken, Liver, Meat by-Products, \r\nWheat Gluten, Turkey, Soy Flour, Corn Starch-Modified, Artificial and Natural Flavors, \r\nCalcium Phosphate, Potassium Chloride, Taurine, Added Color, Salt, Choline Chloride, \r\nThiamine Mononitrate, Vitamin E Supplement, Zinc Sulfate, Ferrous Sulfate, Niacin, \r\nCalcium Pantothenate, Vitamin A Supplement, Menadione Sodium Bisulfite Complex (Source of Vitamin K \r\nActivity), Manganese Sulfate, Copper Sulfate, Pyridoxine Hydrochloride, Riboflavin \r\nSupplement, Vitamin B-12 Supplement, Biotin, Folic Acid, Vitamin D-3 Supplement, \r\nPotassium Iodide. \r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['78'],
#   'name': u'Purina\xae Friskies\xae Meaty Bits Cat Food',
#   'package_weight': u'5.5oz',
#   'price': u'$0.48',
#   'primary_ingredient': u' Chicken\r\n',
#   'product_id': u'1221028',
#   'tag': None,
#   'taurine_min': ['0.05'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/purina-friskies-meaty-bits-cat-food-1601.html?cgid=200004'},
#  {'crude_fat_min': ['... 18.0'],
#   'crude_fiber_max': ['... 4.0'],
#   'crude_protein_min': ['... 40.0'],
#   'flavor': u'Salmon',
#   'food_type': u'Dry Food',
#   'health_consideration': u'General Health',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['... 10.0'],
#   'name': u'BLUE Wilderness\xae Adult Cat Food - Grain Free, Natural, Salmon',
#   'package_weight': u'5Lb',
#   'price': '',
#   'primary_ingredient': u' Salmon\r\n',
#   'product_id': u'5165217',
#   'tag': None,
#   'taurine_min': ['... 0.15'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/blue-wilderness-adult-cat-food---grain-free-natural-salmon-557.html?cgid=200004'},
#  {'ash_max': ['2.7'],
#   'flavor': u'Marinated Chicken',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'ingredients': u' Poultry Broth, Chicken, Liver, Wheat Gluten, Corn Starch \r\nModified, Turkey, Meat by-Products, Natural and Artificial Flavors, Soy Flour, Tricalcium \r\nPhosphate, Salt, Caramel Color, Titanium Dioxide Color, Potassium Chloride, Taurine, \r\nCholine Chloride, Vitamin E Supplement, Thiamine Mononitrate (Vitamin B1), Ferrous \r\nSulfate, Zinc Sulfate, Manganese Sulfate, Vitamin A Supplement, Pyridoxine Hydrochloride (Vitamin B6), \r\nCopper Sulfate, Niacin, Dicalcium Phosphate, Calcium Pantothenate, Riboflavin Supplement (Vitamin B2), \r\nVitamin D3 Supplement, Cobalt Carbonate, Vitamin B12 Supplement, Menadione Sodium \r\nBisulfite Complex (Source of Vitamin K Activity), Folic Acid, Potassium Iodide, \r\nBiotin.\r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['78'],
#   'name': u'Fancy Feast\xae Marinated Morsels Adult Cat Food',
#   'package_weight': u'3oz',
#   'price': u'$0.59',
#   'primary_ingredient': u' Poultry Broth\r\n',
#   'product_id': u'5063018',
#   'tag': None,
#   'taurine_min': ['0.05'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/fancy-feast-marinated-morsels-adult-cat-food-12860.html?cgid=200004'},
#  {'crude_fat_min': ['13.0'],
#   'crude_fiber_max': ['4.5'],
#   'crude_protein_min': ['32.0'],
#   'flavor': u'Poultry',
#   'food_type': u'Dry Food',
#   'ingredients': <br/>,
#   'life_stage': u'Kitten to Adult',
#   'moisture_max': ['12.0'],
#   'name': u'Purina\xae Cat Chow\xae Complete Formula Cat Food',
#   'package_weight': u'22 lbs.',
#   'price': '',
#   'primary_ingredient': u' Poultry By-Product Meal',
#   'product_id': u'5219545',
#   'tag': None,
#   'taurine_min': ['0.15'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/purina-cat-chow-complete-formula-cat-food-2367.html?cgid=200004'},
#  {'health_consideration': u'General Health',
#   'name': u'Purina\xae Pro Plan\xae Adult Cat Food',
#   'price': '',
#   'product_id': u'5178587',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/purina-pro-plan-adult-cat-food-12807.html?cgid=200004'},
#  {'flavor': u'Salmon',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'ingredients': u' Salmon, Fish Broth, Water Sufficient For Processing, \r\nDried Egg Whites, Peas, Natural Flavor, Tomatoes, Carrots, Dried Egg Product, \r\nCanola Oil (preserved With Mixed Tocopherols), Sodium Phosphate, Salt, Calcium \r\nCarbonate, Ground Flaxseed, Guar Gum, Potassium Chloride, Cranberries, Iron \r\nAmino Acid Chelate, Zinc Amino Acid Chelate, Cobalt Amino Acid Chelate, Copper \r\nAmino Acid Chelate, Manganese Amino Acid Chelate, Sodium Selenite, Potassium \r\nIodide, Carrageenan, Vitamin E Supplement, Thiamine Mononitrate, Niacin, Vitamin \r\nB12 Supplement, D-calcium Pantothenate, Pyridoxine Hydrochloride, Vitamin D3 \r\nSupplement, Riboflavin Supplement, Vitamin A Supplement, Biotin, Folic Acid, \r\nCholine Chloride And Taurine \r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'name': u'Wellness\xae Minced Cat Food - Natural, Grain Free',
#   'package_weight': u'3oz',
#   'price': u'$1.49',
#   'primary_ingredient': u' Salmon\r\n',
#   'product_id': u'5178578',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/wellness-minced-cat-food---natural-grain-free-12908.html?cgid=200004'},
#  {'ash_max': ['3.50'],
#   'crude_fat_min': ['6.00'],
#   'crude_fiber_max': ['1.00'],
#   'crude_protein_min': ['12.00'],
#   'flavor': u'Turkey & Salmon',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['78.00'],
#   'name': u'NUTRO\xae NATURAL CHOICE\xae Sliced Adult Cat Food',
#   'package_weight': u'3oz',
#   'price': '',
#   'primary_ingredient': u' Turkey Broth\r\n',
#   'product_id': u'5196581',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/nutro-natural-choice-sliced-adult-cat-food-12895.html?cgid=200004'},
#  {'flavor': u'Turkey Tuscany & Long Grain Rice',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'ingredients': u' Poultry Broth, Turkey, Liver, Wheat Gluten, Long Grain Rice, Spinach, Meat by-Products, Corn Starch-Modified, Artificial and Natural Flavors, Salt, Calcium Phosphate, Soy Protein Concentrate, Added Color, \r\nPotassium Chloride, Taurine, Choline Chloride, Thiamine Mononitrate, Vitamin E Supplement, \r\nNiacin, Zinc Sulfate, Calcium Pantothenate, Vitamin A Supplement, Menadione Sodium \r\nBisulfite Complex (Source of Vitamin K Activity), Ferrous Sulfate, Pyridoxine Hydrochloride, \r\nManganese Sulfate, Riboflavin Supplement, Vitamin B-12 Supplement, Biotin, Copper \r\nSulfate, Folic Acid, Vitamin D-3 Supplement, Potassium Iodide. \r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'name': u'Fancy Feast\xae Medleys Tuscan-Inspired Adult Cat Food',
#   'package_weight': u'3oz',
#   'price': '',
#   'primary_ingredient': u' Poultry Broth\r\n',
#   'product_id': u'5129959',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/fancy-feast-medleys-tuscan-inspired-adult-cat-food-12850.html?cgid=200004'},
#  {'ash_max': ['3.0'],
#   'crude_fat_min': ['0.05'],
#   'crude_fiber_max': ['1.0'],
#   'crude_protein_min': ['7.0'],
#   'flavor': u'Mackerel & Vegetables',
#   'food_type': u'Cat Food',
#   'ingredients': <br/>,
#   'life_stage': u'Adult',
#   'moisture_max': ['92.0'],
#   'name': u'Fancy Feast\xae Creamy Broths Cat Food',
#   'package_weight': u'1.4 oz.',
#   'price': '',
#   'primary_ingredient': u' Fish Broth',
#   'product_id': u'5221049',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/fancy-feast-creamy-broths-cat-food-26824.html?cgid=200004'},
#  {'ash_max': ['3.0'],
#   'crude_fat_min': ['2.0'],
#   'crude_fiber_max': ['1.5'],
#   'crude_protein_min': ['10.0'],
#   'moisture_max': ['82.0'],
#   'name': u'Fancy Feast\xae Medleys Tastemakers Cat Food',
#   'price': '',
#   'product_id': u'5197459',
#   'tag': None,
#   'taurine_min': ['0.05'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/fancy-feast-medleys-tastemakers-cat-food-18355.html?cgid=200004'},
#  {'ash_max': ['6.5'],
#   'crude_fat_max': ['11.5'],
#   'crude_fat_min': ['8.0'],
#   'crude_fiber_max': ['7.0'],
#   'crude_protein_min': ['33.0'],
#   'flavor': u'Chicken',
#   'food_type': u'Dry Food',
#   'ingredients': <br/>,
#   'life_stage': u'Adult',
#   'moisture_max': ['10.0'],
#   'name': u'Authority\xae Hairball Control & Weight Management Adult Cat Food',
#   'package_weight': u'8 lbs.',
#   'price': u'$14.99',
#   'primary_ingredient': u' Chicken',
#   'product_id': u'5220332',
#   'tag': None,
#   'taurine_min': [],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/authority-hairball-control-and-weight-management-adult-cat-food-26336.html?cgid=200004'},
#  {'ash_max': ['3.0'],
#   'crude_fat_min': ['5.0'],
#   'crude_fiber_max': ['1.5'],
#   'crude_protein_min': ['11.0'],
#   'flavor': u'Chicken',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'ingredients': u' Chicken, Chicken Broth, Meat Byproducts, Chicken Liver, Poultry Byproducts, Natural Flavor, Guar Gum, Added Color, Sodium Tripolyphosphate, Potassium Chloride, Calcium Carbonate, Magnesium Sulfate, Potassium Iodide, Zinc Sulfate, Iron Sulfate, Copper Sulfate, Manganese Sulfate, Fish Oil (preserved With Mixed Tocopherols), Choline Chloride, Thiamine Mononitrate (vitamin B1), Vitamin E Supplement, Pyridoxine Hydrochloride (vitamin B6), Vitamin D3 Supplement, Folic Acid, Menadione Sodium Bisulfite Complex (source Of Vitamin K Activity), Dl-methionine, Salt And Taurine\r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['78.0'],
#   'name': u'Sheba Premium Pate Adult Cat Food',
#   'package_weight': u'3oz',
#   'price': u'$0.47',
#   'primary_ingredient': u' Chicken\r\n',
#   'product_id': u'5179917',
#   'tag': None,
#   'taurine_min': ['0.05'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/sheba-premium-pate-adult-cat-food-12878.html?cgid=200004'},
#  {'flavor': u'Chicken & Brown Rice',
#   'food_type': u'Dry Food',
#   'health_consideration': u'Weight Management, Hairball Control',
#   'life_stage': u'Adult 1-10 yrs',
#   'name': u'BLUE\u2122Indoor Health Adult Cat Food - Chicken & Brown Rice',
#   'package_weight': u'15Lb',
#   'price': '',
#   'primary_ingredient': u' Chicken\r\n',
#   'product_id': u'5108707',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/blueandtradeindoor-health-adult-cat-food---chicken-and-brown-rice-366.html?cgid=200004'},
#  {'flavor': u'Tuna',
#   'food_type': u'Wet Food',
#   'ingredients': <br/>,
#   'life_stage': u'Adult',
#   'name': u'Iams\xae Purrfect Delight Cat Food',
#   'package_weight': u'3 oz.',
#   'price': '',
#   'primary_ingredient': u' Fish Broth',
#   'product_id': u'5210201',
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/iams-purrfect-delight-cat-food-20920.html?cgid=200004'},
#  {'ash_max': ['6.5'],
#   'crude_fat_min': ['16.0'],
#   'crude_fiber_max': ['3.0'],
#   'crude_protein_min': ['36.0'],
#   'moisture_max': ['10.0'],
#   'name': u'Simply Nourish\u2122 Adult Cat Food - Natural, Chicken & Rice',
#   'price': '',
#   'product_id': u'5162939',
#   'tag': None,
#   'taurine_min': ['0.20'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/royal-canin-feline-health-nutritionandtrade-indoor-adult-27-cat-food-1188.html?cgid=200004'},
#  {'flavor': u'Other',
#   'food_type': u'Dry Food',
#   'health_consideration': u'Sensitive Stomach, Skin & Coat',
#   'life_stage': u'Adult 1-10 yrs',
#   'name': u'BLUE\u2122 Sensitive Stomach Adult Cat Food',
#   'package_weight': u'15Lb',
#   'price': '',
#   'primary_ingredient': u' Chicken\r\n',
#   'product_id': u'5162799',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/blueandtrade-sensitive-stomach-adult-cat-food-329.html?cgid=200004'},
#  {'ash_max': ['3.0'],
#   'crude_fat_min': ['3.0'],
#   'crude_fiber_max': ['1.0'],
#   'crude_protein_min': ['11.0'],
#   'flavor': u'Salmon & Tuna',
#   'food_type': u'Wet Food',
#   'life_stage': u'Kitten to Senior',
#   'moisture_max': ['78.0'],
#   'name': u'Purina\xae Friskies\xae SauceSations Cat Food',
#   'package_weight': u'5.5 oz.',
#   'price': u'$0.48',
#   'primary_ingredient': u' Water Sufficient for Processing',
#   'product_id': u'5209043',
#   'tag': None,
#   'taurine_min': ['0.05'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/purina-friskies-saucesations-cat-food-20965.html?cgid=200004'},
#  {'ash_max': ['2.75'],
#   'crude_fat_min': ['5.5'],
#   'crude_fiber_max': ['0.5'],
#   'crude_protein_min': ['10'],
#   'flavor': u'Chicken',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'ingredients': u' Chicken Broth, Chicken, Meat By-Products, Liver, Chicken By-Products, Natural Flavors, Brewers Rice, Broccoli, Carrots, Dried Beet Pulp, Flax Meal, Sweet Potatoes, Titanium Dioxide, Guar Gum, Suncured Alfalfa, Potassium Chloride, Brewers Dried Yeast, Dried Egg Product, Minerals (Zinc Oxide, Manganese Sulfate, Copper Sulfate, Potassium Iodide), Choline Chloride, Carrageenan, Vitamins (Vitamin E Supplement, Niacin, Thiamine Mononitrate (source of vitamin B1), Vitamin A Acetate, Calcium Pantothenate, Biotin, Pyridoxine Hydrochloride (source of vitamin B6), Vitamin B12 Supplement, Riboflavin Supplement (source of vitamin B2), Vitamin D3 Supplement, Menadione Dimethylpyrimidinol Bisulfite (source of vitamin K3), Folic Acid), Fructooligosaccharides, Taurine, Salt\r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['78'],
#   'name': u'Iams\xae Proactive Health Pate Adult Cat Food',
#   'package_weight': u'3oz',
#   'price': u'$0.79',
#   'primary_ingredient': u' Chicken Broth\r\n',
#   'product_id': u'5159007',
#   'tag': None,
#   'taurine_min': ['0.05'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/iams-proactive-health-pate-adult-cat-food-12831.html?cgid=200004'},
#  {'flavor': u'Turkey & Vegetable Entr\xc3\xa9e Classic',
#   'food_type': u'Wet Food',
#   'life_stage': u'Adult',
#   'name': u'Purina\xae Pro Plan\xae Savor Adult Cat Food',
#   'package_weight': u'3 oz.',
#   'price': '',
#   'primary_ingredient': u' Turkey',
#   'product_id': u'5209065',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/purina-pro-plan-savor-adult-cat-food-21002.html?cgid=200004'},
#  {'ash_max': ['3.0'],
#   'crude_fat_min': ['2.0'],
#   'crude_fiber_max': ['1.5'],
#   'crude_protein_min': ['10.0'],
#   'flavor': u'Chicken, Tuna & Wild Rice',
#   'food_type': u'Cat Food',
#   'life_stage': u'Adult',
#   'moisture_max': ['82.0'],
#   'name': u'Purina\xae Pro Plan\xae Adult Cat Food - Chicken, Tuna & Wild Rice',
#   'package_weight': u'3 oz.',
#   'price': '',
#   'primary_ingredient': u' Water Sufficient for Processing',
#   'product_id': u'5230668',
#   'tag': None,
#   'taurine_min': ['0.05'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/purina-pro-plan-adult-cat-food---chicken-tuna-and-wild-rice-30077.html?cgid=200004'},
#  {'price': '',
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/wellness-complete-health-cat-food---natural-grain-free-25941.html?cgid=200004'},
#  {'flavor': u'Chicken & Liver',
#   'food_type': u'Wet Food',
#   'health_consideration': u'General Health',
#   'life_stage': u'Adult 1-10 yrs',
#   'name': u'Fancy Feast\xae Sliced Adult Cat Food',
#   'package_weight': u'3oz',
#   'price': u'$0.59',
#   'product_id': u'1221459',
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/fancy-feast-sliced-adult-cat-food-12854.html?cgid=200004'},
#  {'ash_max': ['7.0'],
#   'crude_fat_min': ['20.0'],
#   'crude_fiber_max': ['3.0'],
#   'crude_protein_min': ['34.0'],
#   'flavor': u'Chicken',
#   'food_type': u'Dry Food',
#   'ingredients': <br/>,
#   'life_stage': u'Kitten',
#   'moisture_max': ['10.0'],
#   'name': u'Authority\xae Kitten Food',
#   'package_weight': u'4 lbs.',
#   'price': u'$9.99',
#   'primary_ingredient': u' Chicken',
#   'product_id': u'5220291',
#   'tag': None,
#   'taurine_min': [],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/authority-kitten-food-26334.html?cgid=200004'},
#  {'crude_fat_min': ['16.0'],
#   'crude_fiber_max': ['8.0'],
# ...
#   'food_type': u'Wet Food',
#   'health_consideration': u'Weight Control',
#   'life_stage': u'Adult 1-10 yrs',
#   'name': u"Hill's\xae Prescription Diet\xae Metabolic Advanced Weight Solution Adult Cat Food",
#   'package_weight': u'5.5oz',
#   'price': u'$2.09',
#   'primary_ingredient': u' Pork Liver\r\n',
#   'product_id': u'5197660',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/hills-prescription-diet-metabolic-advanced-weight-solution-adult-cat-food-1714.html?cgid=200004'},
#  {'crude_fat_min': ['3.5'],
#   'crude_fiber_max': ['1.6'],
#   'crude_protein_min': ['6.5'],
#   'flavor': u'Other',
#   'food_type': u'Wet Food',
#   'health_consideration': u'Hypoallergenic',
#   'ingredients': u' Water Sufficient For Processing, Venison By-products, \r\nVenison, Pea Flour, Vegetable Oil, Natural Flavors, Fish Oil, Carrageenan, Pea \r\nProtein, Carob Gum, Sodium Tripolyphosphate, Calcium Sulfate, Taurine, Choline \r\nChloride, Potassium Chloride, DL-alpha-tocopherol Acetate (source Of Vitamin E), \r\nNiacin Supplement, L-ascorbyl-2-polyphosphate (source Of Vitamin C), Thiamine \r\nMononitrate (vitamin B1), Biotin, D-calcium Pantothenate, Riboflavin Supplement \r\n(vitamin B2), Pyridoxine Hydrochloride (vitamin B6), Vitamin B12 Supplement, \r\nFolic Acid, Vitamin D3 Supplement, Zinc Proteinate, Zinc Oxide, Ferrous Sulfate, \r\nCopper Sulfate, Manganous Oxide, Sodium Selenite, Calcium Iodate And Marigold \r\nExtract (Tagetes Erecta L.)\r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['81.5'],
#   'name': u'Royal Canin\xae Veterinary Diet Hypoallergenic PV Adult Cat Food',
#   'package_weight': u'5.6oz',
#   'price': u'$2.85',
#   'primary_ingredient': u' Water\r\n',
#   'product_id': u'5134457',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/royal-canin-veterinary-diet-hypoallergenic-pv-adult-cat-food-1746.html?cgid=200004'},
#  {'flavor': u'Other',
#   'food_type': u'Dry Food',
#   'health_consideration': u'Weight Management',
#   'ingredients': u" Chicken By-product Meal, Corn Gluten Meal,\r\nPork Fat (preserved With Mixed Tocopherols And Citric Acid), Pork\r\nProtein Isolate, Powdered Cellulose, Brewer's Rice, Whole Grain\r\nCorn, Dried Egg Product, Chicken Liver Flavor, Lactic Acid,\r\nL-lysine, Potassium Chloride, Calcium Sulfate, Choline Chloride,\r\nVitamin E Supplement, L-ascorbyl-2-polyphosphate (source Of Vitamin\r\nC), Vitamin E Supplement, Niacin, Thiamine Mononitrate, Vitamin A\r\nSupplement, Calcium Pantothenate, Riboflavin, Biotin, Vitamin B12\r\nSupplement, Pyridoxine Hydrochloride, Folic Acid, Vitamin D3\r\nSupplement, Taurine, DL-methionine, Iodized Salt, Ferrous Sulfate,\r\nZinc Oxide, Copper Sulfate, Manganous Oxide, Calcium Iodate, Sodium\r\nSelenite, L-carnitine, Preserved With Mixed Tocopherols And Citric\r\nAcid, Phosphoric Acid, Beta Carotene And Rosemary Extract",
#   'life_stage': u'Adult 1-10 yrs',
#   'name': u"Hill's\xae Prescription Diet\xae m/d Weight loss- Carbohydrate- Diabetic Adult Cat Food",
#   'package_weight': u'8.5Lb',
#   'price': u'$47.99',
#   'primary_ingredient': u' Chicken By Product Meal\xa0',
#   'product_id': u'5154330',
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/hills-prescription-diet-m%2Fd-weight-loss--carbohydrate--diabetic-adult-cat-food-1111.html?cgid=200004'},
#  {'crude_fat_min': ['5.0'],
#   'crude_fiber_max': ['1.5'],
#   'crude_protein_min': ['8.0'],
#   'flavor': u'Other',
#   'food_type': u'Wet Food',
#   'health_consideration': u'Gastrointestinal',
#   'ingredients': u' Water Sufficient For Processing, Chicken, Chicken Liver, \r\nCorn Four, Chicken By-product, Rice Flour, Pork Plasma, Powdered Cellulose, Fish \r\nOil, Potassium Chloride, Sodium Silico Aluminate, Natural Flavors, Sodium \r\nTripolyphosphate, Carob Gum, Taurine, Calcium Sulphate, Carrageenan, Hydrolyzed \r\nYeast, Choline Chloride, DL-alpha-tocopherol Acetate (source Of Vitamin E), \r\nL-ascorbyl-2-polyphosphate (source Of Vitamin C), Thiamine Mononitrate (vitamin \r\nB1), Niacin Supplement, Biotin, D-calcium Pantothenate, Riboflavin Supplement \r\n(vitamin B2), Pyridoxine Hydrochloride (vitamin B6), Vitamin B12 Supplement, \r\nFolic Acid, Vitamin D3 Supplement, Zinc Proteinate, Zinc Oxide, Ferrous Sulfate, \r\nCopper Sulfate, Manganous Oxide, Sodium Selenite, Calcium Iodate, Marigold \r\nExtract (tagetes Erecta L.) And Magnesium Oxide',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['78.5'],
#   'name': u'Royal Canin\xae Veterinary Diet Gastrointestinal Adult Cat Food',
#   'package_weight': u'5.8oz',
#   'price': u'$2.09',
#   'primary_ingredient': u' Water\r\n',
#   'product_id': u'5148018',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/royal-canin-veterinary-diet-gastrointestinal-adult-cat-food-1748.html?cgid=200004'},
#  {'crude_protein_min': ['30.0',
#    '14.0',
#    '10.5',
#    '10.0',
#    '7.0',
#    '0.65',
#    '0.45',
#    '0.45',
#    '0.08',
#    '500 IU/kg, Taurine (min) 0.1',
#    '(min) 85 mg/kg, Total Omega-6 Fatty Acids* (min) 2.36',
#    '0.15'],
#   'flavor': u'Other',
r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['9.0'],
#   'name': u'Royal Canin\xae Veterinary Diet Hypoallergenic PD Adult Cat Food',
#   'package_weight': u'8.8Lb',
#   'price': u'$63.99',
#   'primary_ingredient': u' Peas\r\n',
#   'product_id': u'5162821',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/royal-canin-veterinary-diet-hypoallergenic-pd-adult-cat-food-904.html?cgid=200004'},
#  {'ash_max': ['2.0'],
#   'crude_fat_max': ['3.5'],
#   'crude_fat_min': ['1.0'],
#   'crude_fiber_max': ['6.0'],
#   'crude_protein_min': ['7.0'],
#   'flavor': u'Liver & Chicken',
#   'food_type': u'Wet Food',
#   'health_consideration': u'Weight Control',
#   'ingredients': u" Water, Pork Liver, Powdered Cellulose, Pork By-products, Corn Starch, Brewer's Rice, Chicken, Corn Gluten Meal, Soybean Oil, Guar Gum, Calcium Carbonate, Dicalcium Phosphate, Calcium Sulfate, Potassium Chloride, DL-methionine, Taurine, Vitamin E Supplement, Iodized Salt, Chicken Liver Flavor, Choline Chloride, L-carnitine, Thiamine Mononitrate, Ascorbic Acid (source Of Vitamin C), Zinc Oxide, Ferrous Sulfate, Beta Carotene, Niacin, Manganous Oxide, Copper Sulfate, Pyridozine Hydrochloride, Calcium Pantothenate, Vitamin B12 Supplement, Riboflavin, Biotin, Vitamin D3 Supplement, Calcium Iodate, Folic Acid, Sodium Selenite\r\n",
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['78.0'],
#   'name': u"Hill's\xae Prescription Diet\xae r/d Weight Loss- Low calorie Adult Cat Food",
#   'package_weight': u'5.5oz',
#   'price': u'$1.89',
#   'primary_ingredient': u' Pork Liver\r\n',
#   'product_id': u'5072388',
#   'tag': None,
#   'taurine_min': ['0.06'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/hills-prescription-diet-r%2Fd-weight-loss--low-calorie-adult-cat-food-1716.html?cgid=200004'},
#  {'flavor': u'Other',
#   'food_type': u'Dry Food',
#   'health_consideration': u'Hypoallergenic',
#   'ingredients': u' Peas, Duck By-product Meal, Coconut Oil, Natural Flavors, Pea Protein, Calcium Sulfate, Vegetable Oil, Sodium Bisulfate, Monocalcium Phosphate, DL-methionine, Fish Oil, Salt, Choline Chloride, Taurine, DL-alpha-tocopherol Acetate (source Of Vitamin E), L-ascorbyl-2-polyphosphate (source Of Vitamin C), Niacin Supplement, Biotin, Riboflavin Supplement (vitamin B2), D-calcium Pantothenate, Pyridoxine Hydrochloride (vitamin B6), Vitamin A Acetate, Thiamine, Zinc Oxide, Zinc Proteinate, Ferrous Sulfate, Manganese Proteinate, Copper Proteinate, Copper Sulfate, Manganous Oxide, Calcium Iodate, Sodium Selenite And Rosemary Extract (preserved With Natural Mixed Tocopherols And Citric Acid)\r\n',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['9.0'],
#   'name': u'Royal Canin\xae Veterinary Diet Hypoallergenic PV Adult Cat Food',
#   'package_weight': u'8.8Lb',
#   'price': u'$63.99',
#   'primary_ingredient': u' Peas\r\n',
#   'product_id': u'5162823',
#   'tag': None,
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/royal-canin-veterinary-diet-hypoallergenic-pv-adult-cat-food-906.html?cgid=200004'},
#  {'ash_max': ['8.0'],
#   'crude_fat_min': ['17.0'],
#   'crude_fiber_max': ['6.0'],
#   'crude_protein_min': ['27.0'],
#   'flavor': u'Other',
#   'food_type': u'Dry Food',
#   'health_consideration': u'Dry & Itchy Skin',
#   'ingredients': u' Ground Yellow Peas, Pea Protein Concentrate, Venison, Ground Green Peas, Pork Fat (Preserved With Mixed Tocopherols And Citric Acid), Powdered Cellulose, Calcium Sulfate, Chicken Liver Flavor, Fish Oil, Lactic Acid, Choline Chloride, DL-methionine, Calcium Carbonate, Potassium Chloride, Taurine, Glyceryl Monostearate, Iodized Salt, Potassium Sulfate, Dicalcium Phosphate, L-ascorbyl-2-polyphosphate (Source Of Vitamin C), Vitamin E Supplement, Niacin, Thiamine Mononitrate, Vitamin A Supplement, Calcium Pantothenate, Biotin, Riboflavin, Vitamin B12 Supplement, Pyridoxine Hydrochloride, Folic Acid, Vitamin D3 Supplement, Cysteine, Ferrous Sulfate, Zinc Oxide, Copper Sulfate, Manganous Oxide, Calcium Iodate, Sodium Selenite, Preserved With Mixed Tocopherols And Citric Acid, Phosphoric Acid, Beta Carotene And Rosemary Extract',
#   'life_stage': u'Adult 1-10 yrs',
#   'moisture_max': ['8.0'],
#   'name': u"Hill's\xae Prescription Diet\xae d/d Skin Support Adult Cat Food",
#   'package_weight': u'8.5Lb',
#   'price': u'$61.99',
#   'primary_ingredient': u' Ground Yellow Peas\r\n',
#   'product_id': u'5162719',
#   'tag': None,
#   'taurine_min': ['0.25'],
#   'url': 'http://www.petsmart.com/cat/food-and-health/food/hills-prescription-diet-d%2Fd-skin-support-adult-cat-food-1107.html?cgid=200004'}]

# %%
#import the pickle file as a dataframe:
#look in pet-products-scraper-data folder
products = pd.read_pickle('/Users/karigoodman/git-archives/pet-products-scraper-data/product_info_df.pkl')
len(products)
products.head(50)
# Out:
#    ash_max crude_fat_max crude_fat_min crude_fiber_max crude_fiber_min  \
# 0    [3.5]           NaN           [2]           [1.5]             NaN
# 1    [3.5]           NaN           [5]             [1]             NaN
# 2    [2.5]           NaN         [2.5]           [1.0]             NaN
# 3    [2.7]           NaN           [2]           [1.5]             NaN
# 4    [2.2]           NaN         [6.5]           [0.8]             NaN
# 5      NaN           NaN           NaN             NaN             NaN
# 6    [2.8]           NaN         [2.0]           [1.5]             NaN
# 7    [2.7]           NaN         [2.0]           [1.0]             NaN
# 8    [2.3]           NaN         [5.0]           [1.0]             NaN
# 9    [6.5]        [15.0]        [12.0]           [5.0]             NaN
# 10     [3]           NaN           [2]           [1.5]             NaN
# 11   [2.7]           NaN         [4.0]           [1.5]             NaN
# 12     NaN           NaN           NaN             NaN             NaN
# 13     NaN           NaN    [... 16.0]       [... 6.0]             NaN
# 14   [3.0]           NaN         [4.5]             NaN             NaN
# 15   [3.5]           NaN         [5.0]           [1.0]             NaN
# 16     NaN           NaN           NaN             NaN             NaN
# 17   [3.0]           NaN        [0.05]           [1.0]             NaN
# 18   [2.7]           NaN         [5.0]           [1.5]             NaN
# 19     NaN           NaN           NaN             NaN             NaN
# 20     NaN           NaN           NaN             NaN             NaN
# 21     NaN           NaN           NaN             NaN             NaN
# 22     NaN           NaN           NaN             NaN             NaN
# 23     NaN           NaN           NaN             NaN             NaN
# 24     NaN           NaN           NaN             NaN             NaN
# 25     NaN           NaN           NaN             NaN             NaN
# 26   [3.5]           NaN         [4.0]           [1.5]             NaN
# 27   [2.5]           NaN         [2.5]             [1]             NaN
# 28     NaN           NaN    [... 18.0]       [... 4.0]             NaN
# 29   [2.7]           NaN           NaN             NaN             NaN
# 30     NaN           NaN        [13.0]           [4.5]             NaN
# 31     NaN           NaN           NaN             NaN             NaN
# 32     NaN           NaN           NaN             NaN             NaN
# 33  [3.50]           NaN        [6.00]          [1.00]             NaN
# 34     NaN           NaN           NaN             NaN             NaN
# 35   [3.0]           NaN        [0.05]           [1.0]             NaN
# 36   [3.0]           NaN         [2.0]           [1.5]             NaN
# 37   [6.5]        [11.5]         [8.0]           [7.0]             NaN
# 38   [3.0]           NaN         [5.0]           [1.5]             NaN
# 39     NaN           NaN           NaN             NaN             NaN
# 40     NaN           NaN           NaN             NaN             NaN
# 41   [6.5]           NaN        [16.0]           [3.0]             NaN
# 42     NaN           NaN           NaN             NaN             NaN
# 43     NaN           NaN           NaN             NaN             NaN
# 44     NaN           NaN           NaN             NaN             NaN
# 45     NaN           NaN           NaN             NaN             NaN
# 46   [3.0]           NaN         [3.0]           [1.0]             NaN
# 47  [2.75]           NaN         [5.5]           [0.5]             NaN
# 48     NaN           NaN           NaN             NaN             NaN
# 49   [3.0]           NaN         [2.0]           [1.5]             NaN
#
#    crude_protein_max crude_protein_min                              flavor  \
# 0                NaN              [13]                  COD, Sole & Shrimp
# 1                NaN              [10]                         Mixed Grill
# 2                NaN             [9.0]                                 NaN
# 3                NaN              [12]                       Seafood Feast
# 4                NaN            [10.0]                             Chicken
# 5                NaN               NaN                              Turkey
# 6                NaN            [10.0]                    Chicken & Cheese
# 7                NaN            [11.0]                                 NaN
# 8                NaN            [10.0]                   Chicken & Herring
# 9                NaN            [33.0]                                 NaN
# 10               NaN            [17.5]                Flaked Fish & Shrimp
# 11               NaN            [10.0]                             Chicken
# 12               NaN               NaN                                 NaN
# 13               NaN        [... 38.0]                               Other
# 14               NaN             [8.0]                                Duck
# 15               NaN            [10.0]                             Poultry
# 16               NaN               NaN                 Whitefish & Cheddar
# 17               NaN             [7.0]            Tuna, Shrimp & Whitefish
# 18               NaN            [10.0]                     Turkey & Giblet
# 19               NaN               NaN                     Tuna Florentine
# 20               NaN               NaN                   Chicken Primavera
# 21               NaN               NaN                     Turkey & Cheese
# 22               NaN            [40.0]                             Chicken
# 23               NaN               NaN                     Shredded Turkey
# 24               NaN               NaN                              Turkey
# 25               NaN               NaN            Turkey, Chicken & Cheese
# 26               NaN            [11.0]                       Chopped Grill
# 27               NaN              [11]                             Chicken
# 28               NaN        [... 40.0]                              Salmon
# 29               NaN               NaN                   Marinated Chicken
# 30               NaN            [32.0]                             Poultry
# 32    Wellness® Minced Cat Food - Natural, Grain Free            3oz   $1.49
# 33       NUTRO® NATURAL CHOICE® Sliced Adult Cat Food            3oz
# 34  Fancy Feast® Medleys Tuscan-Inspired Adult Cat...            3oz
# 35                Fancy Feast® Creamy Broths Cat Food        1.4 oz.
# 36          Fancy Feast® Medleys Tastemakers Cat Food            NaN
# 37  Authority® Hairball Control & Weight Managemen...         8 lbs.  $14.99
# 38                  Sheba Premium Pate Adult Cat Food            3oz   $0.47
# 39  BLUE™Indoor Health Adult Cat Food - Chicken & ...           15Lb
# 40                    Iams® Purrfect Delight Cat Food          3 oz.
# 41  Simply Nourish™ Adult Cat Food - Natural, Chic...            NaN
# 42    BLUE Wilderness® Grain Free Duck Adult Cat Food            NaN
# 43                  Purina® Friskies® Flaked Cat Food          5.5oz   $0.48
# 44  Royal Canin® Feline Health Nutrition™ Indoor A...         3.15Lb
# 45             BLUE™ Sensitive Stomach Adult Cat Food           15Lb
# 46            Purina® Friskies® SauceSations Cat Food        5.5 oz.   $0.48
# 47         Iams® Proactive Health Pate Adult Cat Food            3oz   $0.79
# 48             Purina® Pro Plan® Savor Adult Cat Food          3 oz.
# 49  Purina® Pro Plan® Adult Cat Food - Chicken, Tu...          3 oz.
#
#                   primary_ingredient product_id tag taurine_max  taurine_min  \
# 0                             COD
#     1221059 NaN         NaN       [0.05]
# 1                           Liver
#     1221026 NaN         NaN       [0.05]
# 2                                NaN    5121705 NaN         NaN       [0.05]
# 3                    Chicken Broth
#     5121709 NaN         NaN       [0.05]
# 4                            Chicken    5219423 NaN         NaN       [0.07]
# 5                    Poultry Broth
#     5164703 NaN         NaN          NaN
# 6                            Water
#     5178589 NaN         NaN       [0.05]
# 7                                NaN    5092179 NaN         NaN       [0.05]
# 8                          Chicken
#     5153734 NaN         NaN        [0.1]
# 9                                NaN    5220331 NaN         NaN       [0.15]
# 10                      Ocean Fish
#     1221553 NaN         NaN       [0.05]
# 11                     Chicken Broth    5219391 NaN         NaN       [0.05]
# 12                               NaN    5141590 NaN         NaN          NaN
# 13                         Chicken
#     5173159 NaN         NaN   [... 0.15]
# 14                   Chicken Broth
#     5127570 NaN         NaN       [0.05]
# 15                            Turkey    5179965 NaN         NaN       [0.05]
# 16                      Fish Broth
#     5159870 NaN         NaN          NaN
# 17                        Fish Broth    5221047 NaN         NaN          NaN
# 18                          Turkey
#     5171300 NaN         NaN       [0.05]
# 19                      Fish Broth
#     5113393 NaN         NaN          NaN
# 20                   Poultry Broth
#     5133725 NaN         NaN          NaN
# 21                          Turkey
#     5159874 NaN         NaN          NaN
# 22                         Chicken
#     5127269 NaN         NaN       [0.15]
# 23                   Poultry Broth
#     5113394 NaN         NaN          NaN
# 24                               NaN    5133925 NaN         NaN          NaN
# 25                          Turkey
#     5178840 NaN         NaN          NaN
# 26                   Chicken Broth
#     5121730 NaN         NaN       [0.05]
# 27                         Chicken
#     1221028 NaN         NaN       [0.05]
# 28                          Salmon
#     5165217 NaN         NaN   [... 0.15]
# 29                   Poultry Broth
# 34  http://www.petsmart.com/cat/food-and-health/fo...
# 35  http://www.petsmart.com/cat/food-and-health/fo...
# 36  http://www.petsmart.com/cat/food-and-health/fo...
# 37  http://www.petsmart.com/cat/food-and-health/fo...
# 38  http://www.petsmart.com/cat/food-and-health/fo...
# 39  http://www.petsmart.com/cat/food-and-health/fo...
# 40  http://www.petsmart.com/cat/food-and-health/fo...
# 41  http://www.petsmart.com/cat/food-and-health/fo...
# 42  http://www.petsmart.com/cat/food-and-health/fo...
# 43  http://www.petsmart.com/cat/food-and-health/fo...
# 44  http://www.petsmart.com/cat/food-and-health/fo...
# 45  http://www.petsmart.com/cat/food-and-health/fo...
# 46  http://www.petsmart.com/cat/food-and-health/fo...
# 47  http://www.petsmart.com/cat/food-and-health/fo...
# 48  http://www.petsmart.com/cat/food-and-health/fo...
# 49  http://www.petsmart.com/cat/food-and-health/fo...
#
# [50 rows x 22 columns]

# %%
#are there duplicated IDs? Yes. 
print products.duplicated('product_id').unique()

#which indices?
products[products.duplicated(['product_id'],keep=False)]

#ah, good. it's just the null values, no actual ID numbers included here.
# Out:
# [False True]
#     ash_max crude_fat_max crude_fat_min crude_fiber_max crude_fiber_min  \
# 50      NaN           NaN           NaN             NaN             NaN
# 729     NaN           NaN           NaN             NaN             NaN
# 773     NaN           NaN           NaN             NaN             NaN
#
#     crude_protein_max crude_protein_min flavor food_type health_consideration  \
# 50                NaN               NaN    NaN       NaN                  NaN
# 729               NaN               NaN    NaN       NaN                  NaN
# 773               NaN               NaN    NaN       NaN                  NaN
#
#                            ...                         moisture_max name  \
# 50                         ...                                  NaN  NaN
# 729                        ...                                  NaN  NaN
# 773                        ...                                  NaN  NaN
#
#     package_weight price primary_ingredient product_id tag taurine_max  \
# 50             NaN                      NaN        NaN NaN         NaN
# 729            NaN                      NaN        NaN NaN         NaN
# 773            NaN                      NaN        NaN NaN         NaN
#
#      taurine_min                                                url
# 50           NaN  http://www.petsmart.com/cat/food-and-health/fo...
# 729          NaN  http://www.petsmart.com/cat/food-and-health/fo...
# 773          NaN  http://www.petsmart.com/cat/food-and-health/fo...
#
# [3 rows x 22 columns]

# %%
#to inspect the Beautiful Soup markup of a url that is a specific row of the dataframe:
link = products.iloc[18]['url']
r = urllib.urlopen(link)
soup_obj = BeautifulSoup(r, 'lxml') 
print soup_obj
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="ie6 oldie" lang="en"> <![endif]--><!--[if IE 7]> <html class="ie7 oldie" lang="en"> <![endif]--><!--[if IE 8]> <html class="ie8 oldie" lang="en"> <![endif]--><!--[if gt IE 8]><!--><html lang="en"> <!--<![endif]-->
# <head>
# <script data-dtconfig="cors=1|doNotDetect=mup,kyu,scr,kyd,mdw,dcl|md=Username=a[class='user-account'],OrderConfirmation03=a.pt_order-confirmation|tp=200,50,5,0,10|fa=1|reportUrl=https://uxp.petsmartdmz.com/dynaTraceMonitor" src="http://demandware.edgesuite.net/abbb_prd/on/demandware.static/Sites-PetSmart-Site/-/default/v1487395019558/js/dtagent630_23ehjpqrtx_1305.js" type="text/javascript"></script>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <title>
#
# Grreat Choice® Pate Adult Cat Food | cat Canned Food | PetSmart
#
# </title>
# <link href="http://demandware.edgesuite.net/abbb_prd/on/demandware.static/Sites-PetSmart-Site/-/default/dw3fd9554d/images/favicon-petsmart.ico" rel="shortcut icon"/>
# <meta content="Grreat Choice® Pate Adult Cat Food at PetSmart. Shop all  cat canned food online" name="description"/>
# <meta content="grreat choice® pate adult cat food,grreat choice® pate adult cat food cat canned food,grreat choice® pate adult cat food cat canned food petsmart" name="keywords"/>
# <script language="javascript" src="http://s7d2.scene7.com/s7viewers/html5/js/VideoViewer.js" type="text/javascript"></script>
# <script type="text/javascript">//<!--
# /* <![CDATA[ (head-active_data.js) */
# var dw = (window.dw || {});
# dw.ac = {
#     _analytics: null,
#     _events: [],
#     _category: "",
#     _capture: function(configs) {
#         if (Object.prototype.toString.call(configs) === "[object Array]") {
#             configs.forEach(captureObject);
#             return;
#         }
#         dw.ac._events.push(configs);
#     },
#     capture: function() { dw.ac._capture(arguments); },
#     EV_PRD_SEARCHHIT: "searchhit",
#     EV_PRD_DETAIL: "detail",
#     EV_PRD_RECOMMENDATION: "recommendation",
#     EV_PRD_SETPRODUCT: "setproduct",
#     applyContext: function(context) {
#         if (typeof context === "object" && context.hasOwnProperty("category")) {
#         	dw.ac._category = context.category;
#         }
#     },
#     setDWAnalytics: function(analytics) {
#         dw.ac._analytics = analytics;
#     }
# };
# /* ]]> */
# // -->
# </script><script type="text/javascript">//<!--
# /* <![CDATA[ (head-cquotient.js) */
# var CQuotient = window.CQuotient = {};
# CQuotient.clientId = 'abbb-PetSmart';
# CQuotient.activities = [];
# CQuotient.cqcid='';
# CQuotient.cquid='';
# CQuotient.initFromCookies = function () {
# 	var ca = document.cookie.split(';');
# 	for(var i=0;i < ca.length;i++) {
# 	  var c = ca[i];
# 	  while (c.charAt(0)==' ') c = c.substring(1,c.length);
# 	  if (c.indexOf('cqcid=') == 0) {
# 		  CQuotient.cqcid=c.substring('cqcid='.length,c.length);
# 	  } else if (c.indexOf('cquid=') == 0) {
# 		  CQuotient.cquid=c.substring('cquid='.length,c.length);
# 		  break;
# 	  }
# 	}
# }
# CQuotient.getCQCookieId = function () {
# 	if(window.CQuotient.cqcid == '')
# 		window.CQuotient.initFromCookies();
# 	return window.CQuotient.cqcid;
# };
# CQuotient.getCQUserId = function () {
# 	if(window.CQuotient.cquid == '')
# 		window.CQuotient.initFromCookies();
# 	return window.CQuotient.cquid;
# };
# /* ]]> */
# // -->
# </script>
# <!-- UI -->
# <link href="http://demandware.edgesuite.net/abbb_prd/on/demandware.static/Sites-PetSmart-Site/-/default/v1487395019558/css/style.css" rel="stylesheet"/>
# <!-- Jquery -->
# <script src="http://demandware.edgesuite.net/abbb_prd/on/demandware.static/Sites-PetSmart-Site/-/default/v1487395019558/lib/jquery/jquery-2.1.1.min.js" type="text/javascript"></script>
# <script language="javascript" src="//s7d1.scene7.com/s7viewers/html5/js/MixedMediaViewer/js/s7sdk/utils/Utils.js" type="text/javascript"></script>
# <script language="javascript" type="text/javascript">
# s7sdk.Util.lib.include('s7sdk.common.Container');
# s7sdk.Util.lib.include('s7sdk.set.MediaSet');
# s7sdk.Util.lib.include('s7sdk.set.SpinView');
# s7sdk.Util.lib.include('s7sdk.set.Swatches');
# s7sdk.Util.lib.include('s7sdk.image.ZoomView');
# s7sdk.Util.lib.include('s7sdk.video.VideoPlayer');
# s7sdk.Util.lib.include('s7sdk.image.FlyoutZoomView');
# s7sdk.Util.lib.include('s7sdk.event.Event');
# s7sdk.Util.lib.include('s7sdk.video.VideoControls');
# s7sdk.Util.lib.include('s7sdk.video.VideoPlayer');
# s7sdk.Util.lib.include('s7sdk.common.ControlBar');
# s7sdk.Util.lib.include('s7sdk.common.Button');
# </script>
# <!--[if lte IE 8]>
# <script src="//cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.js" type="text/javascript"></script>
# <script src="https://cdn.rawgit.com/chuckcarpenter/REM-unit-polyfill/master/js/rem.min.js" type="text/javascript"></script>
# <![endif]-->
# <script src="//assets.adobedtm.com/f4f8e610f929b225a35ccb58717094733a5112a1/satelliteLib-e34829ad223c7f083c1391b7cc0dfcd93c24cce6.js"></script>
# <script type="text/javascript">
# if (window.jQuery) {
# jQuery(document).ready(function(){
# if(screen.width < 768){
# jQuery('#footer').append('<a href="/home/" class="full-site-link">View Full Site</a>');
# jQuery('.full-site-link')
# .attr('href', '/on/demandware.store/Sites-PetSmart-Site/default/Home-FullSite')
# .click(function(e) {
# e.preventDefault();
# jQuery.ajax({
# url: '/on/demandware.store/Sites-PetSmart-Site/default/Home-FullSite',
# success: function(){
# window.location.reload();
# }
# });
# }
# );
# }
# });
# }
# </script>
# <link href="http://demandware.edgesuite.net/abbb_prd/on/demandware.static/-/Library-Sites-PetSmartSharedLibrary/default/v1487395019558/css/custom.css" rel="stylesheet" type="text/css"/>
# <link href="/cat/food-and-health/food/canned-food/grreat-choice-pate-adult-cat-food-5171300.html" rel="canonical"/>
# <script src="https://display.ugc.bazaarvoice.com/static/PetSmart/en_US/bvapi.js" type="text/javascript"></script>
# <script language="javascript" type="text/javascript">
# 	var configData = {};
#
#
#     	configData.productId = "12869";
#
#
#     $BV.configure("global", configData);
# </script>
# </head>
# <body>
# <div class="pt_product-details" id="wrapper">
# <!-- MyBuys libraries and style sheet - Place in <head> element -->
# <!-- For secure (HTTPS) pages, change the href in the link element and -->
# <!-- the src in both <script> tags to use 'https' instead of 'http' -->
# <link href="http://t.p.mybuys.com/clients/ZTESTEIGHT/css/styles.css" id="mybuysstyles" rel="stylesheet" type="text/css"/>
# <script src="http://t.p.mybuys.com/js/mybuys4.js" type="text/javascript"></script>
# <script src="http://t.p.mybuys.com/clients/ZTESTEIGHT/js/setup.js" type="text/javascript"></script>
# <!-- End MyBuys libraries and style sheet -->
# <header class="header">
# <div class="header-banner ">
# <div class="banner-container">
# <div class="html-slot-container">
# <div class="html-slot-container"><div class="header-promotion">It's National Adoption Weekend! | <a href="http://www.petsmart.com/store-locator/#page_name=global&amp;link_section=header&amp;link_name=naw&amp;template_type=top_banner&amp;start_date=2-17-2017&amp;end_date=2-20-2017">find a store &gt;</a></div></div>
# </div>
# <!-- utility user menu -->
# <ul class="menu-utility-user">
# <li class="lives-saved">
# 7,296,688 lives saved
# </li>
# <li class="stores" id="headerStoreInfo">
# <a data-lid="find stores &amp; events" data-link-type="o" data-lpos="Header:find stores &amp; events" href="http://www.petsmart.com/store-locator/#page_name=global&amp;link_section=header&amp;link_name=find_more_stores">
# <em class="icon-locator"></em>
# <span>find stores &amp; events</span>
# </a>
# </li>
# <li class="user-info">
# <a class="user-account-sign-in" data-lid="sign in" data-link-type="o" data-lpos="Header:sign in" href="https://www.petsmart.com/account/#page_name=global&amp;link_section=header&amp;link_name=sign_in" maxlength="5">
# sign in
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="top-banner" role="banner">
# <div class="head-container">
# <button class="menu-toggle">
# <em></em>
# <span class="visually-hidden">Menu</span>
# </button>
# <a class="locator hidden-lg" data-lid="Locate Stores" data-link-type="o" data-lpos="Header:Locate Stores" href="http://www.petsmart.com/store-locator/" title="Locate Stores"><em class="icon-locator"></em></a>
# <div class="skip-nav-wrapper">
# <a href="#" id="skip-navigation">skip navigation</a>
# </div>
# <div class="primary-logo">
# <a data-lid="PetSmart" data-link-type="o" data-lpos="Header:PetSmart" href="/" title="Demandware PetSmart Home">
# <img alt="PetSmart" src="http://s7d2.scene7.com/is/image/PetSmart/header-logo?$petsmart_logo$"/>
# <span class="visually-hidden">PetSmart</span>
# </a>
# </div>
# <nav id="navigation" role="navigation">
# <div class="sticky-logo">
# <a data-lid="PetSmart" data-link-type="o" data-lpos="Header:PetSmart" href="/home/" tabindex="-1" title="Demandware PetSmart Home">
# <img alt="PetSmart" src="http://s7d2.scene7.com/is/image/PetSmart/header-logo?$petsmart_logo$"/>
# <span class="visually-hidden">PetSmart</span>
# </a>
# </div>
# <div class="mobile-nav-header hidden-lg">
# <span class="menu-back"><em class="icon-arrow-left"></em>back </span>
# <div class="selected-menu-name"></div>
# <a class="mobile-menu-logo" data-lid="mobile-menu-logo" data-link-type="o" data-lpos="Header:mobile-menu-logo" href="/"><img alt="PetSmart" src="http://s7d2.scene7.com/is/image/PetSmart/header-logo?$petsmart_logo$"/></a>
# <div class="icon-close" id="head-menu-close"></div>
# </div>
# <div class="menu-mobile-scroll">
# <ul class="menu-category level-1">
# <li>
# <em class="menu-item-toggle"></em>
# <a class="first-level-anchor has-sub-menu " data-gtm="dog" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/#page_name=global&amp;link_section=menu&amp;link_name=dog"> dog
# </a>
# <div class="row level-2">
# <div class="sub-menu-flyout">
# <div class="col-lg-8">
# <ul class="menu-horizontal">
# <li>
# <div class="menu-sub-head">Food &amp; Health</div>
# <ul class="level-3">
# <li>
# <a data-gtm="dog:food-&amp;-health:dental-care" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/food-and-health/dental-care/#page_name=global&amp;link_section=menu&amp;link_name=dog_dental_care">
# Dental Care
# </a>
# </li>
# <li>
# <a data-gtm="dog:food-&amp;-health:flea-&amp;-tick" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/food-and-health/flea-and-tick/#page_name=global&amp;link_section=menu&amp;link_name=dog_flea_tick">
# Flea &amp; Tick
# </a>
# </li>
# <li>
# <a data-gtm="dog:food-&amp;-health:food" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/food-and-health/food/#page_name=global&amp;link_section=menu&amp;link_name=dog_food">
# Food
# </a>
# </li>
# <li>
# <a data-gtm="dog:food-&amp;-health:treats-&amp;-rawhide" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/food-and-health/treats-and-rawhide/#page_name=global&amp;link_section=menu&amp;link_name=dog_treats_rawhide">
# Treats &amp; Rawhide
# </a>
# </li>
# <li>
# <a data-gtm="dog:food-&amp;-health:vitamins-&amp;-wellness" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/food-and-health/vitamins-and-wellness/#page_name=global&amp;link_section=menu&amp;link_name=dog_vitamins_wellness">
# Vitamins &amp; Wellness
# </a>
# </li>
# </ul>
# </li>
# <li>
# <div class="menu-sub-head">Supplies &amp; Training</div>
# <ul class="level-3">
# <li>
# <a data-gtm="dog:supplies-&amp;-training:beds-&amp;-blankets" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/supplies-and-training/beds-and-blankets/#page_name=global&amp;link_section=menu&amp;link_name=dog_beds_blankets">
# Beds &amp; Blankets
# </a>
# </li>
# <li>
# <a data-gtm="dog:supplies-&amp;-training:bowls-&amp;-feeders" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/supplies-and-training/bowls-and-feeders/#page_name=global&amp;link_section=menu&amp;link_name=dog_bowls_feeders">
# Bowls &amp; Feeders
# </a>
# </li>
# <li>
# <a data-gtm="dog:supplies-&amp;-training:clothes-&amp;-shoes" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/supplies-and-training/clothes-and-shoes/#page_name=global&amp;link_section=menu&amp;link_name=dog_clothes_shoes">
# Clothes &amp; Shoes
# </a>
# </li>
# <li>
# <a data-gtm="dog:supplies-&amp;-training:collars,-harnesses-&amp;-leashes" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/supplies-and-training/collars-harnesses-and-leashes/#page_name=global&amp;link_section=menu&amp;link_name=dog_collars_harnesses_leashes">
# Collars, Harnesses &amp; Leashes
# </a>
# </li>
# <li>
# <a data-gtm="dog:supplies-&amp;-training:crates,-gates-&amp;-containment" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/supplies-and-training/crates-gates-and-containment/#page_name=global&amp;link_section=menu&amp;link_name=dog_crates_gates_containment">
# Crates, Gates &amp; Containment
# </a>
# </li>
# <li>
# <a data-gtm="dog:supplies-&amp;-training:grooming-supplies" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/supplies-and-training/grooming-supplies/#page_name=global&amp;link_section=menu&amp;link_name=dog_grooming_supplies">
# Grooming Supplies
# </a>
# </li>
# <li>
# <a data-gtm="dog:supplies-&amp;-training:ramps-&amp;-steps" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/supplies-and-training/ramps-and-steps/#page_name=global&amp;link_section=menu&amp;link_name=dog_ramps_steps">
# Ramps &amp; Steps
# </a>
# </li>
# <li>
# <a data-gtm="dog:supplies-&amp;-training:stain-&amp;-odor-removers" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/supplies-and-training/stain-and-odor-removers/">
# Stain &amp; Odor Removers
# </a>
# </li>
# <li>
# <a data-gtm="dog:supplies-&amp;-training:toys" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/supplies-and-training/toys/#page_name=global&amp;link_section=menu&amp;link_name=dog_toys">
# Toys
# </a>
# </li>
# <li>
# <a data-gtm="dog:supplies-&amp;-training:training-&amp;-behavior" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/supplies-and-training/training-and-behavior/#page_name=global&amp;link_section=menu&amp;link_name=dog_training_behavoir">
# Training &amp; Behavior
# </a>
# </li>
# <li>
# <a data-gtm="dog:supplies-&amp;-training:travel-essentials" data-lid="dog" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/dog/supplies-and-training/travel-essentials/#page_name=global&amp;link_section=menu&amp;link_name=dog_travel_essentials">
# Travel Essentials
# </a>
# </li>
# </ul>
# </li>
# <div class="html-slot-container">
# <section class="_GN_navServices ">
# <div class="_GN_navServices__listContainer">
# <div class="_GN_navServices__menuTitle">pet services</div>
# <ul class="_GN_navServices__serviceList">
# <li class="_GN_navServices__listItem"><a class="_GN_navServices__listLink" href="http://www.petsmart.com/pet-services/grooming/#page_name=global&amp;link_section=menu&amp;link_name=dog_grooming_salon">Grooming Salon</a></li>
# <li class="_GN_navServices__listItem"><a class="_GN_navServices__listLink" href="http://www.petsmart.com/pet-services/training/#page_name=global&amp;link_section=menu&amp;link_name=dog_training_classes">Training Classes</a></li>
# <li class="_GN_navServices__listItem"><a class="_GN_navServices__listLink" href="http://www.petsmart.com/pet-services/petshotel/#page_name=global&amp;link_section=menu&amp;link_name=dog_petshotel">PetsHotel Boarding</a></li>
# <li class="_GN_navServices__listItem"><a class="_GN_navServices__listLink" href="http://www.petsmart.com/pet-services/doggie-day-camp/#page_name=global&amp;link_section=menu&amp;link_name=dog_doggie_day_camp">Doggie Day Camp</a></li>
# <li class="_GN_navServices__listItem"><a class="_GN_navServices__listLink" href="http://www.petsmart.com/pet-services/banfield/#page_name=global&amp;link_section=menu&amp;link_name=dog_banfield_pet_hospital">Banfield Pet Hospital</a></li>
# </ul>
# <div class="_GN_navServices__menuTitle">featured shops</div>
# <ul class="_GN_navServices__serviceList">
# <li class="_GN_navServices__listItem"><a class="_GN_navServices__listLink" href="http://www.petsmart.com/dog/featured-shops/gifts-for-dog-lovers/#page_name=global&amp;link_section=menu&amp;link_name=dog_gifts_for_dog_lovers">gifts for dog lovers</a></li>
# <li class="_GN_navServices__listItem"><a class="_GN_navServices__listLink" href="http://www.petsmart.com/featured-shops/new-pet/puppy/?srule=relevance&amp;pmin=0">puppy place</a></li>
# <li class="_GN_navServices__listItem"><a class="_GN_navServices__listLink" href="http://www.petsmart.com/dog/featured-shops/team-shop/#page_name=global&amp;link_section=menu&amp;link_name=dog_team_shop">Team Shop</a></li>
# </ul>
# </div>
# </section>
# </div>
# </ul>
# </div>
# <div class="html-slot-container">
# <!-- _GN_001_01_flyout -->
# <div class="flyoutContainer col-lg-4">
# <section class="_GN_flyout " style="margin-bottom: 2.5rem;">
# <a class="_GN_flyout__link" href="http://www.petsmart.com/featured-brands/ed-ellen-degeneres/?srule=best-sellers&amp;pmin=0#page_name=dog_c1&amp;link_section=slot_2&amp;link_name=edellendegeneres&amp;template_type=cl4&amp;start_date=2-1-2017&amp;end_date=3-5-2017">
# <img alt="ED Ellen DeGeneres logo" class="_GN_flyout__image" src="//s7d2.scene7.com/is/image/PetSmart/GN0306_FEAT_MENU-Dog-Ellen-20170102?$GN0306$"/>
# <div class="_GN_flyout__container">
# <div class="_GN_flyout__title">NEW &amp; EXCLUSIVE</div>
# <div class="_GN_flyout__subtitle">ED Ellen DeGeneres</div>
# <p class="_GN_flyout__message">
#           Introducing a new collection of inspiring pet products.
#           <span class="_GN_flyout__inline-link" href="#">shop now</span>
# </p>
# </div>
# </a>
# </section>
# <section class="_GN_flyout " style="margin-bottom: 2.5rem;">
# <a class="_GN_flyout__link" href="http://www.petsmart.com/sale/dog/food-and-health/food/nutro/?srule=relevance&amp;pmin=0#page_name=global&amp;link_section=menu&amp;link_name=dog_1&amp;template_type=gn_3&amp;start_date=11-28-2016&amp;end_date=1-2-2017">
# <img alt="Nutro dog food" class="_GN_flyout__image" src="//s7d2.scene7.com/is/image/PetSmart/GN0306_FEAT_MENU-Dog-NutroDogFood-20170102?$GN0306$"/>
# <div class="_GN_flyout__container">
# <div class="_GN_flyout__title">FOOD SALE</div>
# <div class="_GN_flyout__subtitle">save up to $6</div>
# <p class="_GN_flyout__message">
#           NUTRO® dog food
#           <span class="_GN_flyout__inline-link" href="#">shop now</span>
# </p>
# </div>
# </a>
# </section>
# <section class="_GN_flyout " style="margin-bottom: 2.5rem;">
# <a class="_GN_flyout__link" href="http://www.petsmart.com/dog/food-and-health/flea-and-tick/advantage+k9-advantix/?prefn1=customSupply&amp;srule=best-sellers&amp;pmin=0&amp;prefv1=6-Pack#page_name=global&amp;link_section=menu&amp;link_name=dog_2&amp;template_type=gn_3&amp;start_date=1-30-2017&amp;end_date=3-5-2017">
# <img alt="K9 Advantix II dog food" class="_GN_flyout__image" src="//s7d2.scene7.com/is/image/PetSmart/5214340?$GN0306$"/>
# <div class="_GN_flyout__container">
# <div class="_GN_flyout__title">FLEA &amp; TICK SALE</div>
# <div class="_GN_flyout__subtitle">BOGO 50% off</div>
# <p class="_GN_flyout__message">
#           entire stock of K9 Advantix and Advantage 6 packs
#           <span class="_GN_flyout__inline-link" href="#">shop now</span>
# </p>
# </div>
# </a>
# </section>
# </div>
# <!-- _GN_001_01_flyout -->
# </div>
# <div class="html-slot-container">
# <section class="_GN_navOther ">
# <div class="_GN_navOther__container">
# <ul class="_GN_navOther__listSection">
# <li class="_GN_navOther__listItem _GN_navOther__listItem-hidden"><div class="_GN_navOther__subHead">more ways to shop</div></li>
# <li class="_GN_navOther__listItem"><a class="_GN_navOther__link _GN_navOther__link-sale" href="http://www.petsmart.com/sale/dog/#page_name=global&amp;link_section=menu&amp;link_name=dog_sale"><span class="_GN_navOther__icon icon-tag"></span>sale</a></li>
# <li class="_GN_navOther__listItem"><a class="_GN_navOther__link" href="http://www.petsmart.com/shop-by-brand/#page_name=global&amp;link_section=menu&amp;link_name=dog_shop_by_brand">shop by brand</a></li>
# <li class="_GN_navOther__listItem"><a class="_GN_navOther__link" href="http://www.petsmart.com/dog/#page_name=global&amp;link_section=menu&amp;link_name=dog_see_all_dog_items">see all dog items</a></li>
# </ul>
# </div>
# </section>
# </div>
# </div>
# </div>
# </li>
# <li>
# <em class="menu-item-toggle"></em>
# <a class="first-level-anchor has-sub-menu " data-gtm="cat" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/#page_name=global&amp;link_section=menu&amp;link_name=cat"> cat
# </a>
# <div class="row level-2">
# <div class="sub-menu-flyout">
# <div class="col-lg-8">
# <ul class="menu-horizontal">
# <li>
# <div class="menu-sub-head">Food &amp; Health</div>
# <ul class="level-3">
# <li>
# <a data-gtm="cat:food-&amp;-health:dental-care" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/food-and-health/dental-care/#page_name=global&amp;link_section=menu&amp;link_name=cat_dental_care">
# Dental Care
# </a>
# </li>
# <li>
# <a data-gtm="cat:food-&amp;-health:flea-&amp;-tick" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/food-and-health/flea-and-tick/#page_name=global&amp;link_section=menu&amp;link_name=cat_flea_tick">
# Flea &amp; Tick
# </a>
# </li>
# <li>
# <a data-gtm="cat:food-&amp;-health:food" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/food-and-health/food/#page_name=global&amp;link_section=menu&amp;link_name=cat_food">
# Food
# </a>
# </li>
# <li>
# <a data-gtm="cat:food-&amp;-health:treats" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/food-and-health/treats/#page_name=global&amp;link_section=menu&amp;link_name=cat_treats">
# Treats
# </a>
# </li>
# <li>
# <a data-gtm="cat:food-&amp;-health:vitamins-&amp;-wellness" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/food-and-health/vitamins-and-wellness/#page_name=global&amp;link_section=menu&amp;link_name=cat_vitamins_wellness">
# Vitamins &amp; Wellness
# </a>
# </li>
# </ul>
# </li>
# <li>
# <div class="menu-sub-head">Supplies &amp; Training</div>
# <ul class="level-3">
# <li>
# <a data-gtm="cat:supplies-&amp;-training:beds-&amp;-blankets" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/supplies-and-training/beds-and-blankets/#page_name=global&amp;link_section=menu&amp;link_name=cat_beds_blankets">
# Beds &amp; Blankets
# </a>
# </li>
# <li>
# <a data-gtm="cat:supplies-&amp;-training:bowls-&amp;-feeders" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/supplies-and-training/bowls-and-feeders/#page_name=global&amp;link_section=menu&amp;link_name=cat_bowls_feeders">
# Bowls &amp; Feeders
# </a>
# </li>
# <li>
# <a data-gtm="cat:supplies-&amp;-training:clothes-&amp;-costumes" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/supplies-and-training/clothes-and-costumes/#page_name=global&amp;link_section=menu&amp;link_name=cat_clothes_costumes">
# Clothes &amp; Costumes
# </a>
# </li>
# <li>
# <a data-gtm="cat:supplies-&amp;-training:collars,-harnesses-&amp;-leashes" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/supplies-and-training/collars-harnesses-and-leashes/#page_name=global&amp;link_section=menu&amp;link_name=cat_collars_harnesses_leashes">
# Collars, Harnesses &amp; Leashes
# </a>
# </li>
# <li>
# <a data-gtm="cat:supplies-&amp;-training:crates,-gates-&amp;-containment" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/supplies-and-training/crates-gates-and-containment/#page_name=global&amp;link_section=menu&amp;link_name=cat_crates_gates_containment">
# Crates, Gates &amp; Containment
# </a>
# </li>
# <li>
# <a data-gtm="cat:supplies-&amp;-training:furniture-&amp;-scratchers" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/supplies-and-training/furniture-and-scratchers/#page_name=global&amp;link_section=menu&amp;link_name=cat_furniture_scratchers">
# Furniture &amp; Scratchers
# </a>
# </li>
# <li>
# <a data-gtm="cat:supplies-&amp;-training:grooming-supplies" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/supplies-and-training/grooming-supplies/#page_name=global&amp;link_section=menu&amp;link_name=cat_grooming_supplies">
# Grooming Supplies
# </a>
# </li>
# <li>
# <a data-gtm="cat:supplies-&amp;-training:litter-&amp;-waste-disposal" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/supplies-and-training/litter-and-waste-disposal/">
# Litter &amp; Waste Disposal
# </a>
# </li>
# <li>
# <a data-gtm="cat:supplies-&amp;-training:repellents" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/supplies-and-training/repellents/#page_name=global&amp;link_section=menu&amp;link_name=cat_repellents">
# Repellents
# </a>
# </li>
# <li>
# <a data-gtm="cat:supplies-&amp;-training:stain-&amp;-odor-removers" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/supplies-and-training/stain-and-odor-removers/#page_name=global&amp;link_section=menu&amp;link_name=cat_stain_odor_removers">
# Stain &amp; Odor Removers
# </a>
# </li>
# <li>
# <a data-gtm="cat:supplies-&amp;-training:toys" data-lid="cat" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/cat/supplies-and-training/toys/#page_name=global&amp;link_section=menu&amp;link_name=cat_toys">
# Toys
# </a>
# </li>
# </ul>
# </li>
# <div class="html-slot-container">
# <section class="_GN_navServices ">
# <div class="_GN_navServices__listContainer">
# <div class="_GN_navServices__menuTitle">pet services</div>
# <ul class="_GN_navServices__serviceList">
# <li class="_GN_navServices__listItem"><a class="_GN_navServices__listLink" href="http://www.petsmart.com/pet-services/grooming/#page_name=global&amp;link_section=menu&amp;link_name=dog_grooming_salon">Grooming Salon</a></li>
# <li class="_GN_navServices__listItem"><a class="_GN_navServices__listLink" href="http://www.petsmart.com/pet-services/petshotel/#page_name=global&amp;link_section=menu&amp;link_name=dog_petshotel">PetsHotel Boarding</a></li>
# <li class="_GN_navServices__listItem"><a class="_GN_navServices__listLink" href="http://www.petsmart.com/pet-services/banfield/#page_name=global&amp;link_section=menu&amp;link_name=dog_banfield_pet_hospital">Banfield Pet Hospital</a></li>
# </ul>
# <div class="_GN_navServices__menuTitle">featured shops</div>
# <ul class="_GN_navServices__serviceList">
# <li class="_GN_navServices__listItem"><a class="_GN_navServices__listLink" href="http://www.petsmart.com/cat/featured-shops/gifts-for-cat-lovers/#page_name=global&amp;link_section=menu&amp;link_name=cat_gift_for_cat_lovers">gifts for cat lovers</a></li>
# </ul>
# </div>
# </section>
# </div>
# </ul>
# </div>
# <div class="html-slot-container">
# <!-- _GN_001_01_flyout -->
# <div class="flyoutContainer col-lg-4">
# <section class="_GN_flyout " style="margin-bottom: 2.5rem;">
# <a class="_GN_flyout__link" href="http://www.petsmart.com/sale/cat/food-and-health/food/nutro/?prefn1=customCategory&amp;srule=relevance&amp;pmin=0&amp;prefv1=Dry%20Food#page_name=global&amp;link_section=menu&amp;link_name=cat_1&amp;template_type=gn_3&amp;start_date=1-30-2017&amp;end_date=3-5-2017">
# <img alt="save up to $3" class="_GN_flyout__image" src="//s7d2.scene7.com/is/image/PetSmart/GN0306_FEAT_MENU-Cat-NutroCatFood-20170102?$GN0306$"/>
# <div class="_GN_flyout__container">
# <div class="_GN_flyout__title">FOOD SALE</div>
# <div class="_GN_flyout__subtitle">save up to $3</div>
# <p class="_GN_flyout__message">
#           large bags of NUTRO<sup>®</sup> cat food
#           <span class="_GN_flyout__inline-link" href="#">shop now</span>
# </p>
# </div>
# </a>
# </section>
# <section class="_GN_flyout " style="margin-bottom: 2.5rem;">
# <a class="_GN_flyout__link" href="http://www.petsmart.com/sale/cat/supplies-and-training/furniture-and-scratchers/whisker-city/?srule=relevance&amp;pmin=0#page_name=global&amp;link_section=menu&amp;link_name=cat_2&amp;template_type=gn_3&amp;start_date=1-30-2017&amp;end_date=3-5-2017">
# <img alt="save 20%" class="_GN_flyout__image" src="//s7d2.scene7.com/is/image/PetSmart/GN0306_FEAT_MENU-Cat-Furniture-20170102?$GN0306$"/>
# <div class="_GN_flyout__container">
# <div class="_GN_flyout__title">FURNITURE SALE</div>
# <div class="_GN_flyout__subtitle">save 20%</div>
# <p class="_GN_flyout__message">
#           select Whisker City<sup>®</sup> cat furniture with in-store pickup
#           <span class="_GN_flyout__inline-link" href="#">shop now</span>
# </p>
# </div>
# </a>
# </section>
# <section class="_GN_flyout " style="margin-bottom: 2.5rem;">
# <a class="_GN_flyout__link" href="http://www.petsmart.com/cat/supplies-and-training/litter-and-waste-disposal/waste-disposal/litter-genie/?srule=price-low-to-high&amp;pmin=0&amp;sz=24&amp;start=0#page_name=global&amp;link_section=menu&amp;link_name=cat_3&amp;template_type=gn_3&amp;start_date=1-30-2017&amp;end_date=3-5-2017">
# <img alt="save $8" class="_GN_flyout__image" src="//s7d2.scene7.com/is/image/PetSmart/GN0306_FEAT_MENU-Cat-LitterGenie-20170102?$GN0306$"/>
# <div class="_GN_flyout__container">
# <div class="_GN_flyout__title">LITTER SALE</div>
# <div class="_GN_flyout__subtitle">save $8</div>
# <p class="_GN_flyout__message">
#           entire stock of Litter Genie<sup>™</sup> Pails
#           <span class="_GN_flyout__inline-link" href="#">shop now</span>
# </p>
# </div>
# </a>
# </section>
# </div>
# <!-- _GN_001_01_flyout -->
# </div>
# <div class="html-slot-container">
# <section class="_GN_navOther ">
# <div class="_GN_navOther__container">
# <ul class="_GN_navOther__listSection">
# <li class="_GN_navOther__listItem _GN_navOther__listItem-hidden"><div class="_GN_navOther__subHead">more ways to shop</div></li>
# <li class="_GN_navOther__listItem"><a class="_GN_navOther__link _GN_navOther__link-sale" href="http://www.petsmart.com/sale/cat/#page_name=global&amp;link_section=menu&amp;link_name=cat_sale"><span class="_GN_navOther__icon icon-tag"></span>sale</a></li>
# <li class="_GN_navOther__listItem"><a class="_GN_navOther__link" href="https://www.petsmart.com/shop-by-brand/#page_name=global&amp;link_section=menu&amp;link_name=cat_shop_by_brand">shop by brand</a></li>
# <li class="_GN_navOther__listItem"><a class="_GN_navOther__link" href="http://www.petsmart.com/cat/#page_name=global&amp;link_section=menu&amp;link_name=cat_see_all_cat_items">see all cat items</a></li>
# </ul>
# </div>
# </section>
# </div>
# </div>
# </div>
# </li>
# <li>
# <em class="menu-item-toggle"></em>
# <a class="first-level-anchor has-sub-menu " data-gtm="fish" data-lid="fish" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/fish/#page_name=global&amp;link_section=menu&amp;link_name=fish"> fish
# </a>
# <div class="row level-2">
# <div class="sub-menu-flyout">
# <div class="col-lg-8">
# <ul class="menu-horizontal">
# <li>
# <div class="menu-sub-head">Food &amp; Care</div>
# <ul class="level-3">
# <li>
# <a data-gtm="fish:food-&amp;-care:disease-treatment" data-lid="fish" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/fish/food-and-care/disease-treatment/#page_name=global&amp;link_section=menu&amp;link_name=fish_disease_treatment">
# Disease Treatment
# </a>
# </li>
# <li>
# <a data-gtm="fish:food-&amp;-care:feeders" data-lid="fish" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/fish/food-and-care/feeders/#page_name=global&amp;link_section=menu&amp;link_name=fish_feeders">
# Feeders
# </a>
# </li>
# <li>
# <a data-gtm="fish:food-&amp;-care:food" data-lid="fish" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/fish/food-and-care/food/#page_name=global&amp;link_section=menu&amp;link_name=fish_food">
# Food
# </a>
# </li>
# <li>
# <a data-gtm="fish:food-&amp;-care:plant-care" data-lid="fish" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/fish/food-and-care/plant-care/#page_name=global&amp;link_section=menu&amp;link_name=fish_plant_care">
# Plant Care
# </a>
# </li>
# <li>
# <a data-gtm="fish:food-&amp;-care:pond-care" data-lid="fish" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/fish/food-and-care/pond-care/#page_name=global&amp;link_section=menu&amp;link_name=fish_pond_care">
# Pond Care
# </a>
# </li>
# <li>
# <a data-gtm="fish:food-&amp;-care:saltwater-aquarium-care" data-lid="fish" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/fish/food-and-care/saltwater-aquarium-care/#page_name=global&amp;link_section=menu&amp;link_name=fish_saltwater_aquarium_care">
# Saltwater Aquarium Care
# </a>
# </li>
# <li>
# <a data-gtm="fish:food-&amp;-care:water-care-&amp;-conditioning" data-lid="fish" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/fish/food-and-care/water-care-and-conditioning/#page_name=global&amp;link_section=menu&amp;link_name=fish_water_care_conditioning">
# Water Care &amp; Conditioning
# </a>
# </li>
# <li>
# <a data-gtm="fish:food-&amp;-care:water-quality-testers" data-lid="fish" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/fish/food-and-care/water-quality-testers/#page_name=global&amp;link_section=menu&amp;link_name=fish_water_quality_testers">
# Water Quality Testers
# </a>
# </li>
# </ul>
# </li>
# <li>
# <div class="menu-sub-head">Supplies</div>
# <ul class="level-3">
# <li>
# <a data-gtm="fish:supplies:aquarium-maintenance" data-lid="fish" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/fish/supplies/aquarium-maintenance/#page_name=global&amp;link_section=menu&amp;link_name=fish_aquarium_maintenance">
# Aquarium Maintenance
# </a>
# </li>
# <li>
# <a data-gtm="fish:supplies:aquariums-&amp;-stands" data-lid="fish" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/fish/supplies/aquariums-and-stands/#page_name=global&amp;link_section=menu&amp;link_name=fish_aquarium_stands">
# Aquariums &amp; Stands
# </a>
# </li>
# <li>
# <a data-gtm="fish:supplies:decor-&amp;-gravel" data-lid="fish" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/fish/supplies/decor-and-gravel/#page_name=global&amp;link_section=menu&amp;link_name=fish_décor_gravel">
# Decor &amp; Gravel
# </a>
# </li>
# <li>
# <a data-gtm="fish:supplies:filters-&amp;-filter-media" data-lid="fish" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/fish/supplies/filters-and-filter-media/#page_name=global&amp;link_section=menu&amp;link_name=fish_filters_filter_media">
# Filters &amp; Filter Media
# </a>
# </li>
# <li>
# <a data-gtm="fish:supplies:heaters-&amp;-thermometers" data-lid="fish" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/fish/supplies/heaters-and-thermometers/#page_name=global&amp;link_section=menu&amp;link_name=fish_heaters_thermometers">
# Heaters &amp; Thermometers
# </a>
# </li>
# <li>
# <a data-gtm="fish:supplies:lighting-&amp;-hoods" data-lid="fish" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/fish/supplies/lighting-and-hoods/#page_name=global&amp;link_section=menu&amp;link_name=fish_lighting_hoods">
# Lighting &amp; Hoods
# </a>
# </li>
# </ul>
# </li>
# <div class="html-slot-container">
# <section class="_GN_navServices ">
# <div class="_GN_navServices__listContainer">
# <div class="_GN_navServices__menuTitle">featured shops</div>
# <ul class="_GN_navServices__serviceList">
# <li class="_GN_navServices__listItem"><a class="_GN_navServices__listLink" href="http://www.petsmart.com/live-pet/live-fish/#page_name=global&amp;link_section=menu&amp;link_name=fish_live_fish">live fish</a></li>
# </ul>
# </div>
# </section>
# </div>
# </ul>
# </div>
# <div class="html-slot-container">
# <!-- _GN_001_01_flyout -->
# <div class="flyoutContainer col-lg-4">
# <section class="_GN_flyout " style="margin-bottom: 2.5rem;">
# <a class="_GN_flyout__link" href="http://www.petsmart.com/fish/supplies/aquariums-and-stands/clear-for-life/?srule=best-sellers&amp;pmin=0&amp;sz=24&amp;start=0#page_name=global&amp;link_section=menu&amp;link_name=fish_1&amp;template_type=gn_3&amp;start_date=1-30-2017&amp;end_date=3-5-2017">
# <img alt="save 25%" class="_GN_flyout__image" src="//s7d2.scene7.com/is/image/PetSmart/GN0306_FEAT_MENU-Fish-Aquarium-20170102?$GN0306$"/>
# <div class="_GN_flyout__container">
# <div class="_GN_flyout__title">AQUARIUM SALE</div>
# <div class="_GN_flyout__subtitle">save 25%</div>
# <p class="_GN_flyout__message">
#           entire stock of Advanced Aqua Tanks Clear-For-Life acrylic aquariums &amp; stands
#           <span class="_GN_flyout__inline-link" href="#">shop now</span>
# </p>
# </div>
# </a>
# </section>
# <section class="_GN_flyout " style="margin-bottom: 2.5rem;">
# <a class="_GN_flyout__link" href="http://www.petsmart.com/fish/supplies/aquariums-and-stands/biorb/?srule=best-sellers&amp;pmin=0#page_name=global&amp;link_section=menu&amp;link_name=fish_2&amp;template_type=gn_3&amp;start_date=1-30-2017&amp;end_date=3-5-2017">
# <img alt="biOrb" class="_GN_flyout__image" src="//s7d2.scene7.com/is/image/PetSmart/5265080?$GN0306$"/>
# <div class="_GN_flyout__container">
# <div class="_GN_flyout__title">ONLINE ONLY</div>
# <div class="_GN_flyout__subtitle">biOrb</div>
# <p class="_GN_flyout__message">
#           new at PetSmart!
#           <span class="_GN_flyout__inline-link" href="#">shop now</span>
# </p>
# </div>
# </a>
# </section>
# <section class="_GN_flyout " style="margin-bottom: 2.5rem;">
# <a class="_GN_flyout__link" href="http://www.petsmart.com/sale/fish/#page_name=global&amp;link_section=menu&amp;link_name=fish_3&amp;template_type=gn_3&amp;start_date=1-30-2017&amp;end_date=3-5-2017">
# <img alt="save on essentials" class="_GN_flyout__image" src="//s7d2.scene7.com/is/image/PetSmart/GN0306_FEAT_MENU-Fish-AmazingAquatics-20170102?$GN0306$"/>
# <div class="_GN_flyout__container">
# <div class="_GN_flyout__title">AMAZING AQUATICS SALE</div>
# <div class="_GN_flyout__subtitle">save on essentials</div>
# <p class="_GN_flyout__message">
#           Get incredible savings on all aquatic must-haves!
#           <span class="_GN_flyout__inline-link" href="#">shop now</span>
# </p>
# </div>
# </a>
# </section>
# </div>
# <!-- _GN_001_01_flyout -->
# </div>
# <div class="html-slot-container">
# <section class="_GN_navOther ">
# <div class="_GN_navOther__container">
# <ul class="_GN_navOther__listSection">
# <li class="_GN_navOther__listItem _GN_navOther__listItem-hidden"><div class="_GN_navOther__subHead">more ways to shop</div></li>
# <li class="_GN_navOther__listItem"><a class="_GN_navOther__link _GN_navOther__link-sale" href="https://www.petsmart.com/sale/fish/#page_name=global&amp;link_section=menu&amp;link_name=fish_sale"><span class="_GN_navOther__icon icon-tag"></span>sale</a></li>
# <li class="_GN_navOther__listItem"><a class="_GN_navOther__link" href="https://www.petsmart.com/shop-by-brand/#page_name=global&amp;link_section=menu&amp;link_name=fish_shop_by_brand">shop by brand</a></li>
# <li class="_GN_navOther__listItem"><a class="_GN_navOther__link" href="http://www.petsmart.com/fish/#page_name=global&amp;link_section=menu&amp;link_name=fish_see_all_fish_items">see all fish items</a></li>
# </ul>
# </div>
# </section>
# </div>
# </div>
# </div>
# </li>
# <li>
# <em class="menu-item-toggle"></em>
# <a class="first-level-anchor has-sub-menu " data-gtm="bird" data-lid="bird" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/bird/#page_name=global&amp;link_section=menu&amp;link_name=bird"> bird
# </a>
# <div class="row level-2">
# <div class="sub-menu-flyout">
# <div class="col-lg-8">
# <ul class="menu-horizontal">
# <li>
# <div class="menu-sub-head">Food &amp; Care</div>
# <ul class="level-3">
# <li>
# <a data-gtm="bird:food-&amp;-care:food" data-lid="bird" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/bird/food-and-care/food/#page_name=global&amp;link_section=menu&amp;link_name=bird_food">
# Food
# </a>
# </li>
# <li>
# <a data-gtm="bird:food-&amp;-care:grooming" data-lid="bird" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/bird/food-and-care/grooming/#page_name=global&amp;link_section=menu&amp;link_name=bird_grooming">
# Grooming
# </a>
# </li>
# <li>
# <a data-gtm="bird:food-&amp;-care:health-care" data-lid="bird" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/bird/food-and-care/health-care/#page_name=global&amp;link_section=menu&amp;link_name=bird_health_care">
# Health Care
# </a>
# </li>
# <li>
# <a data-gtm="bird:food-&amp;-care:treats-&amp;-treat-holders" data-lid="bird" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/bird/food-and-care/treats-and-treat-holders/#page_name=global&amp;link_section=menu&amp;link_name=bird_treats_treat_holders">
# Treats &amp; Treat Holders
# </a>
# </li>
# </ul>
# </li>
# <li>
# <div class="menu-sub-head">Supplies</div>
# <ul class="level-3">
# <li>
# <a data-gtm="bird:supplies:bowls-&amp;-feeders" data-lid="bird" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/bird/supplies/bowls-and-feeders/#page_name=global&amp;link_section=menu&amp;link_name=bird_bowls_feeders">
# Bowls &amp; Feeders
# </a>
# </li>
# <li>
# <a data-gtm="bird:supplies:cages-&amp;-stands" data-lid="bird" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/bird/supplies/cages-and-stands/#page_name=global&amp;link_section=menu&amp;link_name=bird_cages_stands">
# Cages &amp; Stands
# </a>
# </li>
# <li>
# <a data-gtm="bird:supplies:coops-&amp;-outdoor-habitats" data-lid="bird" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/bird/supplies/coops-and-outdoor-habitats/#page_name=global&amp;link_section=menu&amp;link_name=bird_coops_outdoor_habitats">
# Coops &amp; Outdoor Habitats
# </a>
# </li>
# <li>
# <a data-gtm="bird:supplies:litter-&amp;-bedding" data-lid="bird" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/bird/supplies/litter-and-bedding/#page_name=global&amp;link_section=menu&amp;link_name=bird_litter_bedding">
# Litter &amp; Bedding
# </a>
# </li>
# <li>
# <a data-gtm="bird:supplies:stain-&amp;-odor-removers" data-lid="bird" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/bird/supplies/stain-and-odor-removers/#page_name=global&amp;link_section=menu&amp;link_name=bird_stain_odor_removers">
# Stain &amp; Odor Removers
# </a>
# </li>
# <li>
# <a data-gtm="bird:supplies:toys,-perches-&amp;-decor" data-lid="bird" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/bird/supplies/toys-perches-and-decor/#page_name=global&amp;link_section=menu&amp;link_name=bird_toys_perches_décor">
# Toys, Perches &amp; Decor
# </a>
# </li>
# <li>
# <a data-gtm="bird:supplies:wild-birds" data-lid="bird" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/bird/supplies/wild-birds/#page_name=global&amp;link_section=menu&amp;link_name=bird_wild_birds">
# Wild Birds
# </a>
# </li>
# </ul>
# </li>
# <div class="html-slot-container">
# <section class="_GN_navServices ">
# <div class="_GN_navServices__listContainer">
# <div class="_GN_navServices__menuTitle">featured shops</div>
# <ul class="_GN_navServices__serviceList">
# <li class="_GN_navServices__listItem"><a class="_GN_navServices__listLink" href="http://www.petsmart.com/live-pet/live-birds/#page_name=global&amp;link_section=menu&amp;link_name=bird_live_birds">live birds</a></li>
# </ul>
# </div>
# </section>
# </div>
# </ul>
# </div>
# <div class="html-slot-container">
# <!-- _GN_001_01_flyout -->
# <div class="flyoutContainer col-lg-4">
# <section class="_GN_flyout " style="margin-bottom: 2.5rem;">
# <a class="_GN_flyout__link" href="http://www.petsmart.com/sale/bird/supplies/wild-birds/kaytee/?prefn1=customCategory&amp;srule=relevance&amp;pmin=0&amp;prefv1=Food#page_name=global&amp;link_section=menu&amp;link_name=bird_1&amp;template_type=gn_3&amp;start_date=1-30-2017&amp;end_date=3-5-2017">
# <img alt="save 10%" class="_GN_flyout__image" src="//s7d2.scene7.com/is/image/PetSmart/GN0306_FEAT_MENU-Bird-KayteeBirdNutFood-20170102?$GN0306$"/>
# <div class="_GN_flyout__container">
# <div class="_GN_flyout__title">FOOD SALE</div>
# <div class="_GN_flyout__subtitle">save 10%</div>
# <p class="_GN_flyout__message">
#           select KAYTEE<sup>®</sup> wild bird food
#           <span class="_GN_flyout__inline-link" href="#">shop now</span>
# </p>
# </div>
# </a>
# </section>
# <section class="_GN_flyout " style="margin-bottom: 2.5rem;">
# <a class="_GN_flyout__link" href="http://www.petsmart.com/bird/supplies/wild-birds/trixie/?srule=best-sellers&amp;pmin=0#page_name=global&amp;link_section=menu&amp;link_name=bird_2&amp;template_type=gn_3&amp;start_date=1-30-2017&amp;end_date=3-5-2017">
# <img alt="save 20%" class="_GN_flyout__image" src="//s7d2.scene7.com/is/image/PetSmart/GN0306_FEAT_MENU-Bird-Feeder-20170102?$GN0306$"/>
# <div class="_GN_flyout__container">
# <div class="_GN_flyout__title">FEEDER SALE</div>
# <div class="_GN_flyout__subtitle">save 20%</div>
# <p class="_GN_flyout__message">
#           all Trixie wild bird feeders
#           <span class="_GN_flyout__inline-link" href="#">shop now</span>
# </p>
# </div>
# </a>
# </section>
# <section class="_GN_flyout " style="margin-bottom: 2.5rem;">
# <a class="_GN_flyout__link" href="http://www.petsmart.com/bird/supplies/cages-and-stands/aande/?srule=best-sellers&amp;pmin=0#page_name=global&amp;link_section=menu&amp;link_name=bird_3&amp;template_type=gn_3&amp;start_date=1-30-2017&amp;end_date=3-5-2017">
# <img alt="save 30%" class="_GN_flyout__image" src="//s7d2.scene7.com/is/image/PetSmart/GN0306_FEAT_MENU-Bird-Furniture-20170102?$GN0306$"/>
# <div class="_GN_flyout__container">
# <div class="_GN_flyout__title">FURNITURE SALE</div>
# <div class="_GN_flyout__subtitle">save 30%</div>
# <p class="_GN_flyout__message">
#           all A&amp;E Cage Company cages &amp; stands
#           <span class="_GN_flyout__inline-link" href="#">shop now</span>
# </p>
# </div>
# </a>
# </section>
# </div>
# <!-- _GN_001_01_flyout -->
# </div>
# <div class="html-slot-container">
# <section class="_GN_navOther ">
# <div class="_GN_navOther__container">
# <ul class="_GN_navOther__listSection">
# <li class="_GN_navOther__listItem _GN_navOther__listItem-hidden"><div class="_GN_navOther__subHead">more ways to shop</div></li>
# <li class="_GN_navOther__listItem"><a class="_GN_navOther__link _GN_navOther__link-sale" href="http://www.petsmart.com/sale/bird/#page_name=global&amp;link_section=menu&amp;link_name=bird_sale"><span class="_GN_navOther__icon icon-tag"></span>sale</a></li>
# <li class="_GN_navOther__listItem"><a class="_GN_navOther__link" href="https://www.petsmart.com/shop-by-brand/#page_name=global&amp;link_section=menu&amp;link_name=bird_shop_by_brand">shop by brand</a></li>
# <li class="_GN_navOther__listItem"><a class="_GN_navOther__link" href="http://www.petsmart.com/bird/#page_name=global&amp;link_section=menu&amp;link_name=bird_see_all_bird_items">see all bird items</a></li>
# </ul>
# </div>
# </section>
# </div>
# </div>
# </div>
# </li>
# <li>
# <em class="menu-item-toggle"></em>
# <a class="first-level-anchor has-sub-menu " data-gtm="reptile" data-lid="reptile" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/reptile/#page_name=global&amp;link_section=menu&amp;link_name=reptile"> reptile
# </a>
# <div class="row level-2">
# <div class="sub-menu-flyout">
# <div class="col-lg-8">
# <ul class="menu-horizontal">
# <li>
# <div class="menu-sub-head">Food &amp; Care</div>
# <ul class="level-3">
# <li>
# <a data-gtm="reptile:food-&amp;-care:food" data-lid="reptile" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/reptile/food-and-care/food/#page_name=global&amp;link_section=menu&amp;link_name=reptile_food">
# Food
# </a>
# </li>
# <li>
# <a data-gtm="reptile:food-&amp;-care:food-&amp;-water-accessories" data-lid="reptile" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/reptile/food-and-care/food-and-water-accessories/#page_name=global&amp;link_section=menu&amp;link_name=reptile_food_water_accessories">
# Food &amp; Water Accessories
# </a>
# </li>
# <li>
# <a data-gtm="reptile:food-&amp;-care:health-&amp;-wellness" data-lid="reptile" data-link-type="o" data-lpos="Header" href="http://www.petsmart.com/reptile/food-and-care/health-and-wellness/#page_name=global&amp;link_section=menu&amp;link_name=reptile_health_wellness">
# Health &amp; Wellness
# </a>
# </li>
# </ul>
# </li>
# <li>
# <div class="menu-sub-head">Supplies</div>
# <ul class="level-3">
# <li>
# ...
# window.Resources = {"I_AGREE":"I Agree","CLOSE":"Close","NO_THANKS":"No, thanks","SHIP_QualifiesFor":"This shipment qualifies for","CC_LOAD_ERROR":"Couldn't load credit card!","REG_ADDR_ERROR":"Could Not Load Address","BONUS_PRODUCT":"Bonus Product","BONUS_PRODUCTS":"Bonus Products","SELECT_BONUS_PRODUCTS":"Select Bonus Products","SELECT_BONUS_PRODUCT":"product.selectbonusproduct","BONUS_PRODUCT_MAX":"The maximum number of bonus products has been selected. Please remove one in order to add additional bonus products.","BONUS_PRODUCT_TOOMANY":"You have selected too many bonus products. Please change the quantity.","SIMPLE_SEARCH":"Fetch...","SUBSCRIBE_EMAIL_DEFAULT":"Email Address","CURRENCY_SYMBOL":"$","CURRENCY_CODE":"USD","MISSINGVAL":"Please enter {0}","IN_FAVORITES":"in favorites","SERVER_ERROR":"Server connection failed!","MISSING_LIB":"jQuery is undefined.","BAD_RESPONSE":"Bad response - parser error!","INVALID_PHONE":"Please enter valid phone number.","REMOVE":"remove","QTY":"Qty","EMPTY_IMG_ALT":"remove","COMPARE_BUTTON_LABEL":"Compare Items","COMPARE_CONFIRMATION":"This will remove the first product added for comparison. Is that OK?","COMPARE_REMOVE_FAIL":"Unable to remove item from list","COMPARE_ADD_FAIL":"Unable to add item to list","ADD_TO_CART_FAIL":"Unable to add item '{0}' to cart","REGISTRY_SEARCH_ADVANCED_CLOSE":"Close Advanced Search","GIFT_CERT_INVALID":"Invalid gift certificate code.","GIFT_CERT_BALANCE":"Your current gift certificate balance is","GIFT_CERT_AMOUNT_INVALID":"Gift Certificate can only be purchased with a minimum of 5 and maximum of 5000","INVALID_NAME":"Please enter your name.","GIFT_CERT_MISSING":"Please enter a gift certificate code.","INVALID_OWNER":"This appears to be a credit card number. Please enter the name of the card holder.","COUPON_CODE_MISSING":"Please enter a promo code.","COOKIES_DISABLED":"Your browser is currently not set to accept cookies. Please turn this functionality on or check if you have another program set to block cookies.","BML_AGREE_TO_TERMS":"You must agree to the terms and conditions","CHAR_LIMIT_MSG":"You have {0} characters left out of {1}","CONFIRM_DELETE":"Do you want to remove this {0}?","TITLE_GIFTREGISTRY":"gift registry","TITLE_ADDRESS":"address","TITLE_CREDITCARD":"credit card","SERVER_CONNECTION_ERROR":"Server connection failed!","IN_STOCK_DATE":"The expected in-stock date is {0}.","ITEM_STATUS_NOTAVAILABLE":"This item is currently not available.","INIFINITESCROLL":"Show All","STORE_NEAR_YOU":"What's available at a store near you","SELECT_STORE":"Select Store","SELECTED_STORE":"Selected Store","PREFERRED_STORE":"Preferred Store","SET_PREFERRED_STORE":"Set Preferred Store","ENTER_ZIP":"Enter ZIP Code","INVALID_ZIP":"Please enter a valid ZIP Code","SEARCH":"Search","CHANGE_LOCATION":"Change Location","CONTINUE_WITH_STORE":"Continue with preferred store","CONTINUE":"Continue","SEE_MORE":"See More Stores","SEE_LESS":"See Fewer Stores","QUICK_VIEW":"Quick View","ADOPTION_COUNT":"7,296,688","SALE_CATEGORIES":["dog","cat","fish","bird","reptile","small pet","learning"],"REDIRECT_PDPWISHLIST":"Product-Show?pid=","SAVE_STORE":"save store","MY_STORE":"my store","enablepayeezytoken":true,"maximumGiftCard":10,"maximumQuantity":500,"VALIDATE_FNAME":"Please enter first name.","VALIDATE_LNAME":"Please enter last name.","VALIDATE_INVALIDFNAME":"Please enter a valid first name.","VALIDATE_INVALIDLNAME":"Please enter a valid last name.","VALIDATE_INVALIDNAME":"Please enter a valid name.","VALIDATE_REQUIRED":"This field is required.","VALIDATE_REMOTE":"Please fix this field.","VALIDATE_EMAIL":"Please enter valid email address.","VALIDATE_URL":"Please enter a valid URL.","VALIDATE_DATE":"Please enter a valid date.","VALIDATE_DATEISO":"Please enter a valid date ( ISO ).","VALIDATE_NUMBER":"Please enter a valid number.","VALIDATE_DIGITS":"Please enter only digits.","VALIDATE_CREDITCARD":"Please enter valid credit card number.","VALIDATE_EQUALTO":"Please enter the same value  ...
# window.Urls = {"appResources":"/on/demandware.store/Sites-PetSmart-Site/default/Resources-Load","pageInclude":"/on/demandware.store/Sites-PetSmart-Site/default/Page-Include","continueUrl":"http://www.petsmart.com/on/demandware.store/Sites-PetSmart-Site/default/Product-ShowInCategory/C1496637697","staticPath":"http://demandware.edgesuite.net/abbb_prd/on/demandware.static/Sites-PetSmart-Site/-/default/v1487395019558/","addGiftCert":"/on/demandware.store/Sites-PetSmart-Site/default/GiftCert-Purchase","minicartGC":"/on/demandware.store/Sites-PetSmart-Site/default/GiftCert-ShowMiniCart","minicartwishlist":"/on/demandware.store/Sites-PetSmart-Site/default/Cart-MiniCart","addProduct":"/on/demandware.store/Sites-PetSmart-Site/default/Cart-AddProduct","minicart":"/on/demandware.store/Sites-PetSmart-Site/default/Cart-MiniAddProduct","cartShow":"/cart/","giftRegAdd":"https://www.petsmart.com/on/demandware.store/Sites-PetSmart-Site/default/Address-GetAddressDetails?addressID=","paymentsList":"https://www.petsmart.com/account/credit-cards/","addressesList":"https://www.petsmart.com/on/demandware.store/Sites-PetSmart-Site/default/Address-IncludeAddressList","wishlistAddress":"https://www.petsmart.com/on/demandware.store/Sites-PetSmart-Site/default/Wishlist-SetShippingAddress","deleteAddress":"/on/demandware.store/Sites-PetSmart-Site/default/Address-Delete","getProductUrl":"/on/demandware.store/Sites-PetSmart-Site/default/Product-Show","getBonusProducts":"/on/demandware.store/Sites-PetSmart-Site/default/Product-GetBonusProducts","addBonusProduct":"/on/demandware.store/Sites-PetSmart-Site/default/Cart-AddBonusProduct","getSetItem":"/on/demandware.store/Sites-PetSmart-Site/default/Product-GetSetItem","productDetail":"/on/demandware.store/Sites-PetSmart-Site/default/Product-Detail","getAvailability":"/on/demandware.store/Sites-PetSmart-Site/default/Product-GetAvailability","removeImg":"http://demandware.edgesuite.net/abbb_prd/on/demandware.static/Sites-PetSmart-Site/-/default/dwc8e53f09/images/icon_remove.gif","searchsuggest":"/on/demandware.store/Sites-PetSmart-Site/default/Search-GetSuggestions","productNav":"/on/demandware.store/Sites-PetSmart-Site/default/Product-Productnav","summaryRefreshURL":"/on/demandware.store/Sites-PetSmart-Site/default/COBilling-UpdateSummary","billingSelectCC":"https://www.petsmart.com/on/demandware.store/Sites-PetSmart-Site/default/COBilling-SelectCreditCard","updateAddressDetails":"https://www.petsmart.com/on/demandware.store/Sites-PetSmart-Site/default/COShipping-UpdateAddressDetails","updateAddressDetailsBilling":"https://www.petsmart.com/on/demandware.store/Sites-PetSmart-Site/default/COBilling-UpdateAddressDetails","shippingMethodsJSON":"https://www.petsmart.com/on/demandware.store/Sites-PetSmart-Site/default/COShipping-GetApplicableShippingMethodsJSON","shippingMethodsList":"https://www.petsmart.com/on/demandware.store/Sites-PetSmart-Site/default/COShipping-UpdateShippingMethodList","selectShippingMethodsList":"https://www.petsmart.com/on/demandware.store/Sites-PetSmart-Site/default/COShipping-SelectShippingMethod","resetPaymentForms":"/on/demandware.store/Sites-PetSmart-Site/default/COBilling-ResetPaymentForms","compareShow":"/on/demandware.store/Sites-PetSmart-Site/default/Compare-Show","compareAdd":"/on/demandware.store/Sites-PetSmart-Site/default/Compare-AddProduct","compareRemove":"/on/demandware.store/Sites-PetSmart-Site/default/Compare-RemoveProduct","compareEmptyImage":"http://demandware.edgesuite.net/abbb_prd/on/demandware.static/Sites-PetSmart-Site/-/default/dw4f8f8347/images/comparewidgetempty.png","giftCardCheckBalance":"https://www.petsmart.com/on/demandware.store/Sites-PetSmart-Site/default/COBilling-GetGiftCertificateBalance","redeemGiftCert":"https://www.petsmart.com/on/demandware.store/Sites-PetSmart-Site/default/COBilling-RedeemGiftCertificateJson","addCoupon":"https://www.petsmart.com/on/demandware.store/Sites-PetSmart-Site/default/Cart-AddCoupon","addCouponCheckOut":"https://www.petsmart. ...
# window.SitePreferences = {"LISTING_INFINITE_SCROLL":false,"LISTING_REFINE_SORT":true,"LISTING_SEARCHSUGGEST_LEGACY":true,"STORE_PICKUP":true,"DONATION_PRODUCT":"5148157","COOKIE_HINT":false};
# window.User = {"zip":null,"storeId":null};
# }());
# </script>
# <script src="http://demandware.edgesuite.net/abbb_prd/on/demandware.static/Sites-PetSmart-Site/-/default/v1487395019558/js/app.js"></script>
# <script type="text/javascript">var digitalData = {"product":{"productInfo":{"color":"","quantity":"1","price":0.43,"parentSku":"12869","productID":"5171300","productName":"Grreat Choice® Pate Adult Cat Food","sku":"002","manufacture":"0000030094","outStockproductID":"5171300","size":"5.5 Oz","flavor":"Turkey & Giblets"},"category":{"primaryCategory":"cat","subCategory1":"Food & Health","subCategory2":"Food","subCategory3":"Canned Food","pageType":"Product Detail","categoryId":"200027"}},"cart":{"item":0},"event":{"eventInfo":{"eventName":""}},"page":{"pageInfo":{"pageName":"Grreat Choice® Pate Adult Cat Food","destinationURL":"www.petsmart.com%2Fcat%2Ffood-and-health%2Ffood%2Fgrreat-choice-pate-adult-cat-food-12869.html%3Fcgid%3D200004"},"productPages":{"findingMethods":"Browsing","productViewType":"Main Product"},"attributes":{"language":"en","country":"us","server":"www.petsmart.com","pageType":"Product Detail","appType":"Web"},"customer":{"customerInfo":{"Loginstatus":"Not Recognised"}},"category":{"primaryCategory":"cat","subCategory1":"Food & Health","subCategory2":"Food","subCategory3":"Canned Food","pageType":"Product Detail","categoryId":"200027"}},"customer":{"customerInfo":{"customerID":"","email":"","janrainID":"","registrationStatus":""}}};</script>
# <script>pageContext = {"title":"Grreat Choice® Pate Adult Cat Food","type":"product","ns":"product"};</script>
# <script>
# var meta = "";
# var keywords = "Grreat Choice&reg; Pate Adult Cat Food";
# </script>
# <script src="http://demandware.edgesuite.net/abbb_prd/on/demandware.static/-/Library-Sites-PetSmartSharedLibrary/default/v1487395019558/js/custom.js" type="text/javascript"></script>
# <script type="text/javascript">_satellite.pageBottom();</script>
# <div class="generic-overlay hidden-wrapper">
# <div class="generic-error-screen-wrapper">
# <div class="generic-error-image">
# <div class="content-asset"><!-- dwMarker="content" dwContentID="320ea1aaf6ec14959f055c1065" -->
# <img alt="" src="//s7d2.scene7.com/is/image/PetSmart/CO1401_ERROR_MODAL-DogTangled-20160818?$generic-error-large$"/>
# </div> <!-- End content-asset -->
# </div>
# <div class="generic-error-content">
# <h3>oops! something went wrong</h3>
# <h4>We are facing some technical issues. Please try again later.</h4>
# <div class="generic-error-btn-wrapper">
# <button class="generic-error-close-btn" type="button">close</button>
# </div>
# </div>
# </div>
# </div>
# <!-- Start: WAYPOINT INLINE FEEDBACK LINK EXAMPLE -->
# <style>
# /* CSS for standard-resolution devices */
# .oo_inline {
# padding: 0 0 0 13px;
# }
# .oo_inline_icon {
# background-image: url(/on/demandware.static/Sites-PetSmart-Site/-/en_US/onlineopinionV5/oo_icon.gif);
# background-size: 100%;
# background-repeat: no-repeat;
# display: block;
# float: left;
# height: 9px;
# width: 9px;
# top: 13px;
# position: absolute;
# }
# /* CSS for high-resolution retina devices */
# @media only screen and (-Webkit-min-device-pixel-ratio: 1.5), only screen and (-moz-min-device-pixel-ratio: 1.5), only screen and (-o-min-device-pixel-ratio: 3/2), only screen and (min-device-pixel-ratio: 1.5) {
# .oo_inline_icon {
# background-image: url(/on/demandware.static/Sites-PetSmart-Site/-/en_US/onlineopinionV5/oo_icon_retina.gif);
# background-size: 100%;
# }
# }
# </style>
# <!-- <a href="#" id="oo_inline_waypoint" class="oo_inline" onclick="OOo.oo_launch(event, 'oo_feedback')"><span class="oo_inline_icon" /></span></a> -->
# <!-- End: WAYPOINT INLINE FEEDBACK LINK EXAMPLE -->
# <!-- MAIN OL STYLESHEET JS -->
# <script charset="windows-1252" language="javascript" src="/on/demandware.static/Sites-PetSmart-Site/-/en_US/onlineopinionV5/oo_style.js" type="text/javascript"></script>
# <!-- CUSTOM OL STYLESHEET JS -->
# <script charset="windows-1252" language="javascript" src="/on/demandware.static/Sites-PetSmart-Site/-/en_US/onlineopinionV5/oo_custom_waypoint_styles.js" type="text/javascript"></script>
# <!-- MAIN OL ENGINE MINI-->
# <script charset="windows-1252" language="javascript" src="/on/demandware.static/Sites-PetSmart-Site/-/en_US/onlineopinionV5/oo_engine.min.js" type="text/javascript"></script>
# <!-- WAYPOINT FEEDBACK CONFIGURATION -->
# <script charset="windows-1252" language="javascript" src="/on/demandware.static/Sites-PetSmart-Site/-/en_US/onlineopinionV5/oo_conf_custom_waypoint.js" type="text/javascript"></script>
# <!-- EXIT FEEDBACK CONFIGURATION -->
# <script charset="windows-1252" language="javascript" src="/on/demandware.static/Sites-PetSmart-Site/-/en_US/onlineopinionV5/oo_conf_exit.js" type="text/javascript"></script>
# <!-- INVITATION FEEDBACK CONFIGURATION -->
# <script charset="windows-1252" language="javascript" src="/on/demandware.static/Sites-PetSmart-Site/-/en_US/onlineopinionV5/oo_conf_invite.js" type="text/javascript"></script>
# <!-- END: OnlineOpinion v5+ -->
# <meta content="Grreat Choice® Pate Adult Cat Food" property="og:title"/>
# <meta content="product" property="og:type"/>
# <meta content="/cat/food-and-health/food/canned-food/grreat-choice-pate-adult-cat-food-5171300.html" property="og:url"/>
# <meta content="null" property="og:description"/>
# <meta content="PetSmart" property="og:site_name"/>
# <meta content="USD 0.43" property="og:price:amount"/>
# <meta content="USD" property="og:price:currency"/>
# <meta content="product" name="twitter:card"/>
# <meta content="@petsmart" name="twitter:site"/>
# <meta content="Grreat Choice® Pate Adult Cat Food" name="twitter:title"/>
# <meta content="null" name="twitter:description"/>
# <meta content="@petsmart" name="twitter:creator"/>
# <meta content="USD 0.43" name="twitter:data1"/>
# <meta content="Price" name="twitter:label1"/>
# </div> <!-- /pt_product-details -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NGQNND');</script>
# <!-- End Google Tag Manager -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-NGQNND" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- Demandware Analytics code 1.0 (body_end-analytics-tracking-asynch.js) -->
# <script type="text/javascript">//<!--
# /* <![CDATA[ */
# function trackPage() {
#     try{
#         var trackingUrl = "http://www.petsmart.com/on/demandware.store/Sites-PetSmart-Site/default/__Analytics-Tracking";
#         var dwAnalytics = dw.__dwAnalytics.getTracker(trackingUrl);
#         if (typeof dw.ac == "undefined") {
#             dwAnalytics.trackPageView();
#         } else {
#             dw.ac.setDWAnalytics(dwAnalytics);
#         }
#     }catch(err) {};
# }
# /* ]]> */
# // -->
# </script>
# <script async="async" onload="trackPage()" src="http://demandware.edgesuite.net/abbb_prd/on/demandware.static/Sites-PetSmart-Site/-/default/v1487395019558/internal/jscript/dwanalytics-16.9.js" type="text/javascript"></script>
# <!-- Demandware Active Data (body_end-active_data.js) -->
# <script async="async" src="http://demandware.edgesuite.net/abbb_prd/on/demandware.static/Sites-PetSmart-Site/-/default/v1487395019558/internal/jscript/dwac-16.9.js" type="text/javascript"></script><!-- CQuotient Activity Tracking (body_end-cquotient.js) -->
# <script async="async" src="https://cdn.cquotient.com/js/v2/gretel.min.js" type="text/javascript"></script>
# </div></body>
# </html>

# %%
#inspecting one of the columns to see how clean the scrape was. It is pretty
#good, though there are a couple instances of the wrong information. 

products.package_weight.unique()
# Out:
# array([u'3oz', u'5.5oz', nan, u'6 oz.', u'3 oz', u'2Lb', u'13oz',
#        u'1.4 oz.', u'12Lb', u'5.5 oz', u'5Lb', u'22 lbs.', u'8 lbs.',
#        u'15Lb', u'3 oz.', u'3.15Lb', u'5.5 oz.', u'4 lbs.', u'3Lb',
#        u'16Lb', u'2.6 oz.', u'7Lb', u'(12) 2.75oz', u'2.8 oz.', u'6.5Lb',
#        u'3.5Lb', u'11Lb', u'6Lb', u'22Lb', u'2.5 oz.', u'6.3Lb',
#        u'11 lbs.', u'2.47 oz.', u'32ct', u'5 lbs.', u'14Lb', u'13.5oz',
#        u'1.36 kg. (3 lbs.)', u'24ct of 5.5oz cans', u'5.8 oz.', u'15lb',
#        u'4 Salmon, 3 Snapper & 3 Shrimp.', u'24ct', u'12 (3oz) Pouches',
#        u'2.75 oz.', u'4.5LB', u'7 lbs.', u'12 Packs', u'24ct of 3oz',
#        u'5.5 lbs.', u'12 Pack', u'2.5Lb', u'5 lb', u'11.5 lbs.',
#        u'11.3 lbs.', u'6.75oz', u'13.5Lb', u'14.2Lb',
#        u'(3)Tuna, (4)Tuna & Whitefish, (3)Sardine & Mackerel Entr\xc3\xa9es',
#        u'5.1 lbs.', u'12ct', u'2 Lb',
#        u'4 Chicken, 3 Chicken & Beef, and 3 Chicken & Duck.',
#        u'5Lb\r\n14oz', u'1.98 lbs.', u'5.14Lb', u'5 oz.',
#        u'12 packs of 2.75oz', u'13.5 lbs.', u'2.24 lbs.', u'13Lb',
#        u'3 loafs of 5.5oz', u'6 lbs.', u'3.2 lbs.', u'3.15 lbs.', u'1Lb',
#        u'4Lb', u'3 lbs.', u'2.9 oz.', u'1.25 lbs.', u'19.2 Lb', u'17.6Lb',
#        u'3.5 oz.', u'8.8 lbs.', u'7.7Lb', u'8.5Lb', u'8.8Lb', u'5.8oz',
#        u'4.4Lb', u'6.6Lb', u'5.6oz'], dtype=object)
